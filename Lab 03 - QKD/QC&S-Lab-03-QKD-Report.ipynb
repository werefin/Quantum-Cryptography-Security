# %% [markdown]
# ## Quantum Cryptography & Security: lab report 03 - QKD

# %% [markdown]
# ## Mounting Google Drive, dataset & imports

# %%
# This script would mount the drive onto the Colab Notebook
# If there is a drive mounted, the notebook would return:
# "Mounted at /content/drive" or "Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True)"
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to experimental data
experimental_data_path = "/content/drive/My Drive/QCS-Lab-03-QKD-Data/"

# %%
import argparse
import numpy as np
import pandas as pd
import os
import warnings
from google.colab import files as gc_files

# %%
# Ignore all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Decoding the keys from data files

# %%
def decoding_keys(filename, maxiter):
    '''
    Read the data from the filename file given as argument and decode the keys encoded.

    Each file contains key blocks of different lengths. A file begins with 8 bytes that code for
    a uint64 big-endian, which is the length N of the block (in bytes).
    After these first 8 bytes, N bytes (= 8*N bits) of raw keys follow.
    After the N bytes, another block begins.

    Each QKD state is represented by two bits.
    Encoding of raw-keys.alice: (00, H), (01, V), (10, D), (11, A) A not used in the three state protocol
    Encoding of raw-keys.decoy: (00, Strong Intensity), (01, Low Intensity), (10, Unused), (11, Unused)
    Encoding of raw-keys.bob: (00, H), (01, V), (10, D), (11, A).

    This code saves the decoded keys in a csv file with the corresponding block length.

    Parameters:
      filename: path to the file to read.
      maxiter: maximum number of keys to read.
    '''
    keys = []
    block_sizes = []
    # Decode file
    bytes = np.fromfile(filename, dtype='uint8')
    i = 0
    while i < len(bytes):
        block_size = int.from_bytes(bytes[i:i+8], byteorder='big')
        i += 8
        b = bytes[i:i + block_size]
        key = np.unpackbits(b, bitorder='little')
        i += block_size
        keys.append(key)
        block_sizes.append(block_size)
    # Decode keys
    decoded_states = []
    decoded_keys = []
    decoded_basis = []
    count = 0
    for k in keys:
        print('Decoding key:', count, 'of', len(keys))
        states = []
        basis = []
        bits = []
        k = np.split(k, len(k)//2)
        if filename[-5:] == 'alice' or filename[-3:] == 'bob':
            for pair in k: # 0 basis Z (key), 1 basis X (check), H/D bit 1, V/A bit 0
                if (pair==[0, 0]).all():
                    states.append('H')
                    bits.append('0')
                    basis.append('0')
                elif (pair==[0, 1]).all():
                    states.append('V')
                    bits.append('1')
                    basis.append('0')
                elif (pair==[1, 0]).all():
                    states.append('D')
                    bits.append('0')
                    basis.append('1')
                elif (pair==[1, 1]).all():
                    states.append('A')
                    bits.append('1')
                    basis.append('1')
            decoded_keys.append(''.join(bits))
            decoded_states.append(''.join(states))
            decoded_basis.append(''.join(basis))
            if maxiter != None and count == maxiter - 1:
              break
            count += 1
        else:
            for pair in k:
                if (pair==[0, 0]).all():
                    states.append('S')
                elif (pair==[0, 1]).all():
                    states.append('L')
                elif (pair==[1, 0]).all():
                    states.append('Unused')
                elif (states==[1, 1]).all():
                    states.append('Unused')
            decoded_states.append(''.join(states))
            if maxiter != None and count == maxiter - 1:
              break
            count += 1
    if filename[-5:] == 'alice' or filename[-3:] == 'bob':
        decoded_keys = np.array(decoded_keys, dtype=object)
        decoded_basis = np.array(decoded_basis, dtype=object)
    block_sizes = np.array(block_sizes, dtype=int)
    decoded_states = np.array(decoded_states, dtype=object)
    # Check if keys are correct
    print ('Decoded key (first 3 bytes):', decoded_states[0][:12])
    return decoded_keys, decoded_basis, block_sizes, decoded_states

# %%
def decoding_keys_to_csv(filename, maxiter):
    if not os.path.exists('/content/decoded_keys/'):
      os.mkdir('/content/decoded_keys/')
    dir = '/content/decoded_keys/'
    decoded_keys, decoded_basis, block_sizes, decoded_states = decoding_keys(filename, maxiter)
    df = pd.DataFrame(decoded_states, columns=['states'])
    df['block_size'] = block_sizes[:maxiter]
    if filename[-5:] == 'alice' or filename[-3:] == 'bob':
        df['key'] = decoded_keys
        df['basis'] = decoded_basis
    if filename[-5:] == 'alice':
        df.to_csv(dir + '/decoded_keys_alice.csv', index=False)
    elif filename[-3:] == 'bob':
        df.to_csv(dir + '/decoded_keys_bob.csv', index=False)
    elif filename[-5:] == 'decoy':
        df.to_csv(dir + '/decoded_keys_decoy.csv', index=False)
    print("Done!")

# %%
decoding_keys_to_csv(experimental_data_path + 'raw-keys.alice', 2926)
decoding_keys_to_csv(experimental_data_path + 'raw-keys.bob', 2926)
decoding_keys_to_csv(experimental_data_path + 'raw-keys.decoy', 2926)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# Decoding key: 856 of 2926
# Decoding key: 857 of 2926
# Decoding key: 858 of 2926
# Decoding key: 859 of 2926
# Decoding key: 860 of 2926
# Decoding key: 861 of 2926
# Decoding key: 862 of 2926
# Decoding key: 863 of 2926
# Decoding key: 864 of 2926
# Decoding key: 865 of 2926
# Decoding key: 866 of 2926
# Decoding key: 867 of 2926
# Decoding key: 868 of 2926
# Decoding key: 869 of 2926
# Decoding key: 870 of 2926
# Decoding key: 871 of 2926
# Decoding key: 872 of 2926
# Decoding key: 873 of 2926
# Decoding key: 874 of 2926
# Decoding key: 875 of 2926
# Decoding key: 876 of 2926
# Decoding key: 877 of 2926
# Decoding key: 878 of 2926
# Decoding key: 879 of 2926
# Decoding key: 880 of 2926
# Decoding key: 881 of 2926
# Decoding key: 882 of 2926
# Decoding key: 883 of 2926
# Decoding key: 884 of 2926
# Decoding key: 885 of 2926
# Decoding key: 886 of 2926
# Decoding key: 887 of 2926
# Decoding key: 888 of 2926
# Decoding key: 889 of 2926
# Decoding key: 890 of 2926
# Decoding key: 891 of 2926
# Decoding key: 892 of 2926
# Decoding key: 893 of 2926
# Decoding key: 894 of 2926
# Decoding key: 895 of 2926
# Decoding key: 896 of 2926
# Decoding key: 897 of 2926
# Decoding key: 898 of 2926
# Decoding key: 899 of 2926
# Decoding key: 900 of 2926
# Decoding key: 901 of 2926
# Decoding key: 902 of 2926
# Decoding key: 903 of 2926
# Decoding key: 904 of 2926
# Decoding key: 905 of 2926
# Decoding key: 906 of 2926
# Decoding key: 907 of 2926
# Decoding key: 908 of 2926
# Decoding key: 909 of 2926
# Decoding key: 910 of 2926
# Decoding key: 911 of 2926
# Decoding key: 912 of 2926
# Decoding key: 913 of 2926
# Decoding key: 914 of 2926
# Decoding key: 915 of 2926
# Decoding key: 916 of 2926
# Decoding key: 917 of 2926
# Decoding key: 918 of 2926
# Decoding key: 919 of 2926
# Decoding key: 920 of 2926
# Decoding key: 921 of 2926
# Decoding key: 922 of 2926
# Decoding key: 923 of 2926
# Decoding key: 924 of 2926
# Decoding key: 925 of 2926
# Decoding key: 926 of 2926
# Decoding key: 927 of 2926
# Decoding key: 928 of 2926
# Decoding key: 929 of 2926
# Decoding key: 930 of 2926
# Decoding key: 931 of 2926
# Decoding key: 932 of 2926
# Decoding key: 933 of 2926
# Decoding key: 934 of 2926
# Decoding key: 935 of 2926
# Decoding key: 936 of 2926
# Decoding key: 937 of 2926
# Decoding key: 938 of 2926
# Decoding key: 939 of 2926
# Decoding key: 940 of 2926
# Decoding key: 941 of 2926
# Decoding key: 942 of 2926
# Decoding key: 943 of 2926
# Decoding key: 944 of 2926
# Decoding key: 945 of 2926
# Decoding key: 946 of 2926
# Decoding key: 947 of 2926
# Decoding key: 948 of 2926
# Decoding key: 949 of 2926
# Decoding key: 950 of 2926
# Decoding key: 951 of 2926
# Decoding key: 952 of 2926
# Decoding key: 953 of 2926
# Decoding key: 954 of 2926
# Decoding key: 955 of 2926
# Decoding key: 956 of 2926
# Decoding key: 957 of 2926
# Decoding key: 958 of 2926
# Decoding key: 959 of 2926
# Decoding key: 960 of 2926
# Decoding key: 961 of 2926
# Decoding key: 962 of 2926
# Decoding key: 963 of 2926
# Decoding key: 964 of 2926
# Decoding key: 965 of 2926
# Decoding key: 966 of 2926
# Decoding key: 967 of 2926
# Decoding key: 968 of 2926
# Decoding key: 969 of 2926
# Decoding key: 970 of 2926
# Decoding key: 971 of 2926
# Decoding key: 972 of 2926
# Decoding key: 973 of 2926
# Decoding key: 974 of 2926
# Decoding key: 975 of 2926
# Decoding key: 976 of 2926
# Decoding key: 977 of 2926
# Decoding key: 978 of 2926
# Decoding key: 979 of 2926
# Decoding key: 980 of 2926
# Decoding key: 981 of 2926
# Decoding key: 982 of 2926
# Decoding key: 983 of 2926
# Decoding key: 984 of 2926
# Decoding key: 985 of 2926
# Decoding key: 986 of 2926
# Decoding key: 987 of 2926
# Decoding key: 988 of 2926
# Decoding key: 989 of 2926
# Decoding key: 990 of 2926
# Decoding key: 991 of 2926
# Decoding key: 992 of 2926
# Decoding key: 993 of 2926
# Decoding key: 994 of 2926
# Decoding key: 995 of 2926
# Decoding key: 996 of 2926
# Decoding key: 997 of 2926
# Decoding key: 998 of 2926
# Decoding key: 999 of 2926
# Decoding key: 1000 of 2926
# Decoding key: 1001 of 2926
# Decoding key: 1002 of 2926
# Decoding key: 1003 of 2926
# Decoding key: 1004 of 2926
# Decoding key: 1005 of 2926
# Decoding key: 1006 of 2926
# Decoding key: 1007 of 2926
# Decoding key: 1008 of 2926
# Decoding key: 1009 of 2926
# Decoding key: 1010 of 2926
# Decoding key: 1011 of 2926
# Decoding key: 1012 of 2926
# Decoding key: 1013 of 2926
# Decoding key: 1014 of 2926
# Decoding key: 1015 of 2926
# Decoding key: 1016 of 2926
# Decoding key: 1017 of 2926
# Decoding key: 1018 of 2926
# Decoding key: 1019 of 2926
# Decoding key: 1020 of 2926
# Decoding key: 1021 of 2926
# Decoding key: 1022 of 2926
# Decoding key: 1023 of 2926
# Decoding key: 1024 of 2926
# Decoding key: 1025 of 2926
# Decoding key: 1026 of 2926
# Decoding key: 1027 of 2926
# Decoding key: 1028 of 2926
# Decoding key: 1029 of 2926
# Decoding key: 1030 of 2926
# Decoding key: 1031 of 2926
# Decoding key: 1032 of 2926
# Decoding key: 1033 of 2926
# Decoding key: 1034 of 2926
# Decoding key: 1035 of 2926
# Decoding key: 1036 of 2926
# Decoding key: 1037 of 2926
# Decoding key: 1038 of 2926
# Decoding key: 1039 of 2926
# Decoding key: 1040 of 2926
# Decoding key: 1041 of 2926
# Decoding key: 1042 of 2926
# Decoding key: 1043 of 2926
# Decoding key: 1044 of 2926
# Decoding key: 1045 of 2926
# Decoding key: 1046 of 2926
# Decoding key: 1047 of 2926
# Decoding key: 1048 of 2926
# Decoding key: 1049 of 2926
# Decoding key: 1050 of 2926
# Decoding key: 1051 of 2926
# Decoding key: 1052 of 2926
# Decoding key: 1053 of 2926
# Decoding key: 1054 of 2926
# Decoding key: 1055 of 2926
# Decoding key: 1056 of 2926
# Decoding key: 1057 of 2926
# Decoding key: 1058 of 2926
# Decoding key: 1059 of 2926
# Decoding key: 1060 of 2926
# Decoding key: 1061 of 2926
# Decoding key: 1062 of 2926
# Decoding key: 1063 of 2926
# Decoding key: 1064 of 2926
# Decoding key: 1065 of 2926
# Decoding key: 1066 of 2926
# Decoding key: 1067 of 2926
# Decoding key: 1068 of 2926
# Decoding key: 1069 of 2926
# Decoding key: 1070 of 2926
# Decoding key: 1071 of 2926
# Decoding key: 1072 of 2926
# Decoding key: 1073 of 2926
# Decoding key: 1074 of 2926
# Decoding key: 1075 of 2926
# Decoding key: 1076 of 2926
# Decoding key: 1077 of 2926
# Decoding key: 1078 of 2926
# Decoding key: 1079 of 2926
# Decoding key: 1080 of 2926
# Decoding key: 1081 of 2926
# Decoding key: 1082 of 2926
# Decoding key: 1083 of 2926
# Decoding key: 1084 of 2926
# Decoding key: 1085 of 2926
# Decoding key: 1086 of 2926
# Decoding key: 1087 of 2926
# Decoding key: 1088 of 2926
# Decoding key: 1089 of 2926
# Decoding key: 1090 of 2926
# Decoding key: 1091 of 2926
# Decoding key: 1092 of 2926
# Decoding key: 1093 of 2926
# Decoding key: 1094 of 2926
# Decoding key: 1095 of 2926
# Decoding key: 1096 of 2926
# Decoding key: 1097 of 2926
# Decoding key: 1098 of 2926
# Decoding key: 1099 of 2926
# Decoding key: 1100 of 2926
# Decoding key: 1101 of 2926
# Decoding key: 1102 of 2926
# Decoding key: 1103 of 2926
# Decoding key: 1104 of 2926
# Decoding key: 1105 of 2926
# Decoding key: 1106 of 2926
# Decoding key: 1107 of 2926
# Decoding key: 1108 of 2926
# Decoding key: 1109 of 2926
# Decoding key: 1110 of 2926
# Decoding key: 1111 of 2926
# Decoding key: 1112 of 2926
# Decoding key: 1113 of 2926
# Decoding key: 1114 of 2926
# Decoding key: 1115 of 2926
# Decoding key: 1116 of 2926
# Decoding key: 1117 of 2926
# Decoding key: 1118 of 2926
# Decoding key: 1119 of 2926
# Decoding key: 1120 of 2926
# Decoding key: 1121 of 2926
# Decoding key: 1122 of 2926
# Decoding key: 1123 of 2926
# Decoding key: 1124 of 2926
# Decoding key: 1125 of 2926
# Decoding key: 1126 of 2926
# Decoding key: 1127 of 2926
# Decoding key: 1128 of 2926
# Decoding key: 1129 of 2926
# Decoding key: 1130 of 2926
# Decoding key: 1131 of 2926
# Decoding key: 1132 of 2926
# Decoding key: 1133 of 2926
# Decoding key: 1134 of 2926
# Decoding key: 1135 of 2926
# Decoding key: 1136 of 2926
# Decoding key: 1137 of 2926
# Decoding key: 1138 of 2926
# Decoding key: 1139 of 2926
# Decoding key: 1140 of 2926
# Decoding key: 1141 of 2926
# Decoding key: 1142 of 2926
# Decoding key: 1143 of 2926
# Decoding key: 1144 of 2926
# Decoding key: 1145 of 2926
# Decoding key: 1146 of 2926
# Decoding key: 1147 of 2926
# Decoding key: 1148 of 2926
# Decoding key: 1149 of 2926
# Decoding key: 1150 of 2926
# Decoding key: 1151 of 2926
# Decoding key: 1152 of 2926
# Decoding key: 1153 of 2926
# Decoding key: 1154 of 2926
# Decoding key: 1155 of 2926
# Decoding key: 1156 of 2926
# Decoding key: 1157 of 2926
# Decoding key: 1158 of 2926
# Decoding key: 1159 of 2926
# Decoding key: 1160 of 2926
# Decoding key: 1161 of 2926
# Decoding key: 1162 of 2926
# Decoding key: 1163 of 2926
# Decoding key: 1164 of 2926
# Decoding key: 1165 of 2926
# Decoding key: 1166 of 2926
# Decoding key: 1167 of 2926
# Decoding key: 1168 of 2926
# Decoding key: 1169 of 2926
# Decoding key: 1170 of 2926
# Decoding key: 1171 of 2926
# Decoding key: 1172 of 2926
# Decoding key: 1173 of 2926
# Decoding key: 1174 of 2926
# Decoding key: 1175 of 2926
# Decoding key: 1176 of 2926
# Decoding key: 1177 of 2926
# Decoding key: 1178 of 2926
# Decoding key: 1179 of 2926
# Decoding key: 1180 of 2926
# Decoding key: 1181 of 2926
# Decoding key: 1182 of 2926
# Decoding key: 1183 of 2926
# Decoding key: 1184 of 2926
# Decoding key: 1185 of 2926
# Decoding key: 1186 of 2926
# Decoding key: 1187 of 2926
# Decoding key: 1188 of 2926
# Decoding key: 1189 of 2926
# Decoding key: 1190 of 2926
# Decoding key: 1191 of 2926
# Decoding key: 1192 of 2926
# Decoding key: 1193 of 2926
# Decoding key: 1194 of 2926
# Decoding key: 1195 of 2926
# Decoding key: 1196 of 2926
# Decoding key: 1197 of 2926
# Decoding key: 1198 of 2926
# Decoding key: 1199 of 2926
# Decoding key: 1200 of 2926
# Decoding key: 1201 of 2926
# Decoding key: 1202 of 2926
# Decoding key: 1203 of 2926
# Decoding key: 1204 of 2926
# Decoding key: 1205 of 2926
# Decoding key: 1206 of 2926
# Decoding key: 1207 of 2926
# Decoding key: 1208 of 2926
# Decoding key: 1209 of 2926
# Decoding key: 1210 of 2926
# Decoding key: 1211 of 2926
# Decoding key: 1212 of 2926
# Decoding key: 1213 of 2926
# Decoding key: 1214 of 2926
# Decoding key: 1215 of 2926
# Decoding key: 1216 of 2926
# Decoding key: 1217 of 2926
# Decoding key: 1218 of 2926
# Decoding key: 1219 of 2926
# Decoding key: 1220 of 2926
# Decoding key: 1221 of 2926
# Decoding key: 1222 of 2926
# Decoding key: 1223 of 2926
# Decoding key: 1224 of 2926
# Decoding key: 1225 of 2926
# Decoding key: 1226 of 2926
# Decoding key: 1227 of 2926
# Decoding key: 1228 of 2926
# Decoding key: 1229 of 2926
# Decoding key: 1230 of 2926
# Decoding key: 1231 of 2926
# Decoding key: 1232 of 2926
# Decoding key: 1233 of 2926
# Decoding key: 1234 of 2926
# Decoding key: 1235 of 2926
# Decoding key: 1236 of 2926
# Decoding key: 1237 of 2926
# Decoding key: 1238 of 2926
# Decoding key: 1239 of 2926
# Decoding key: 1240 of 2926
# Decoding key: 1241 of 2926
# Decoding key: 1242 of 2926
# Decoding key: 1243 of 2926
# Decoding key: 1244 of 2926
# Decoding key: 1245 of 2926
# Decoding key: 1246 of 2926
# Decoding key: 1247 of 2926
# Decoding key: 1248 of 2926
# Decoding key: 1249 of 2926
# Decoding key: 1250 of 2926
# Decoding key: 1251 of 2926
# Decoding key: 1252 of 2926
# Decoding key: 1253 of 2926
# Decoding key: 1254 of 2926
# Decoding key: 1255 of 2926
# Decoding key: 1256 of 2926
# Decoding key: 1257 of 2926
# Decoding key: 1258 of 2926
# Decoding key: 1259 of 2926
# Decoding key: 1260 of 2926
# Decoding key: 1261 of 2926
# Decoding key: 1262 of 2926
# Decoding key: 1263 of 2926
# Decoding key: 1264 of 2926
# Decoding key: 1265 of 2926
# Decoding key: 1266 of 2926
# Decoding key: 1267 of 2926
# Decoding key: 1268 of 2926
# Decoding key: 1269 of 2926
# Decoding key: 1270 of 2926
# Decoding key: 1271 of 2926
# Decoding key: 1272 of 2926
# Decoding key: 1273 of 2926
# Decoding key: 1274 of 2926
# Decoding key: 1275 of 2926
# Decoding key: 1276 of 2926
# Decoding key: 1277 of 2926
# Decoding key: 1278 of 2926
# Decoding key: 1279 of 2926
# Decoding key: 1280 of 2926
# Decoding key: 1281 of 2926
# Decoding key: 1282 of 2926
# Decoding key: 1283 of 2926
# Decoding key: 1284 of 2926
# Decoding key: 1285 of 2926
# Decoding key: 1286 of 2926
# Decoding key: 1287 of 2926
# Decoding key: 1288 of 2926
# Decoding key: 1289 of 2926
# Decoding key: 1290 of 2926
# Decoding key: 1291 of 2926
# Decoding key: 1292 of 2926
# Decoding key: 1293 of 2926
# Decoding key: 1294 of 2926
# Decoding key: 1295 of 2926
# Decoding key: 1296 of 2926
# Decoding key: 1297 of 2926
# Decoding key: 1298 of 2926
# Decoding key: 1299 of 2926
# Decoding key: 1300 of 2926
# Decoding key: 1301 of 2926
# Decoding key: 1302 of 2926
# Decoding key: 1303 of 2926
# Decoding key: 1304 of 2926
# Decoding key: 1305 of 2926
# Decoding key: 1306 of 2926
# Decoding key: 1307 of 2926
# Decoding key: 1308 of 2926
# Decoding key: 1309 of 2926
# Decoding key: 1310 of 2926
# Decoding key: 1311 of 2926
# Decoding key: 1312 of 2926
# Decoding key: 1313 of 2926
# Decoding key: 1314 of 2926
# Decoding key: 1315 of 2926
# Decoding key: 1316 of 2926
# Decoding key: 1317 of 2926
# Decoding key: 1318 of 2926
# Decoding key: 1319 of 2926
# Decoding key: 1320 of 2926
# Decoding key: 1321 of 2926
# Decoding key: 1322 of 2926
# Decoding key: 1323 of 2926
# Decoding key: 1324 of 2926
# Decoding key: 1325 of 2926
# Decoding key: 1326 of 2926
# Decoding key: 1327 of 2926
# Decoding key: 1328 of 2926
# Decoding key: 1329 of 2926
# Decoding key: 1330 of 2926
# Decoding key: 1331 of 2926
# Decoding key: 1332 of 2926
# Decoding key: 1333 of 2926
# Decoding key: 1334 of 2926
# Decoding key: 1335 of 2926
# Decoding key: 1336 of 2926
# Decoding key: 1337 of 2926
# Decoding key: 1338 of 2926
# Decoding key: 1339 of 2926
# Decoding key: 1340 of 2926
# Decoding key: 1341 of 2926
# Decoding key: 1342 of 2926
# Decoding key: 1343 of 2926
# Decoding key: 1344 of 2926
# Decoding key: 1345 of 2926
# Decoding key: 1346 of 2926
# Decoding key: 1347 of 2926
# Decoding key: 1348 of 2926
# Decoding key: 1349 of 2926
# Decoding key: 1350 of 2926
# Decoding key: 1351 of 2926
# Decoding key: 1352 of 2926
# Decoding key: 1353 of 2926
# Decoding key: 1354 of 2926
# Decoding key: 1355 of 2926
# Decoding key: 1356 of 2926
# Decoding key: 1357 of 2926
# Decoding key: 1358 of 2926
# Decoding key: 1359 of 2926
# Decoding key: 1360 of 2926
# Decoding key: 1361 of 2926
# Decoding key: 1362 of 2926
# Decoding key: 1363 of 2926
# Decoding key: 1364 of 2926
# Decoding key: 1365 of 2926
# Decoding key: 1366 of 2926
# Decoding key: 1367 of 2926
# Decoding key: 1368 of 2926
# Decoding key: 1369 of 2926
# Decoding key: 1370 of 2926
# Decoding key: 1371 of 2926
# Decoding key: 1372 of 2926
# Decoding key: 1373 of 2926
# Decoding key: 1374 of 2926
# Decoding key: 1375 of 2926
# Decoding key: 1376 of 2926
# Decoding key: 1377 of 2926
# Decoding key: 1378 of 2926
# Decoding key: 1379 of 2926
# Decoding key: 1380 of 2926
# Decoding key: 1381 of 2926
# Decoding key: 1382 of 2926
# Decoding key: 1383 of 2926
# Decoding key: 1384 of 2926
# Decoding key: 1385 of 2926
# Decoding key: 1386 of 2926
# Decoding key: 1387 of 2926
# Decoding key: 1388 of 2926
# Decoding key: 1389 of 2926
# Decoding key: 1390 of 2926
# Decoding key: 1391 of 2926
# Decoding key: 1392 of 2926
# Decoding key: 1393 of 2926
# Decoding key: 1394 of 2926
# Decoding key: 1395 of 2926
# Decoding key: 1396 of 2926
# Decoding key: 1397 of 2926
# Decoding key: 1398 of 2926
# Decoding key: 1399 of 2926
# Decoding key: 1400 of 2926
# Decoding key: 1401 of 2926
# Decoding key: 1402 of 2926
# Decoding key: 1403 of 2926
# Decoding key: 1404 of 2926
# Decoding key: 1405 of 2926
# Decoding key: 1406 of 2926
# Decoding key: 1407 of 2926
# Decoding key: 1408 of 2926
# Decoding key: 1409 of 2926
# Decoding key: 1410 of 2926
# Decoding key: 1411 of 2926
# Decoding key: 1412 of 2926
# Decoding key: 1413 of 2926
# Decoding key: 1414 of 2926
# Decoding key: 1415 of 2926
# Decoding key: 1416 of 2926
# Decoding key: 1417 of 2926
# Decoding key: 1418 of 2926
# Decoding key: 1419 of 2926
# Decoding key: 1420 of 2926
# Decoding key: 1421 of 2926
# Decoding key: 1422 of 2926
# Decoding key: 1423 of 2926
# Decoding key: 1424 of 2926
# Decoding key: 1425 of 2926
# Decoding key: 1426 of 2926
# Decoding key: 1427 of 2926
# Decoding key: 1428 of 2926
# Decoding key: 1429 of 2926
# Decoding key: 1430 of 2926
# Decoding key: 1431 of 2926
# Decoding key: 1432 of 2926
# Decoding key: 1433 of 2926
# Decoding key: 1434 of 2926
# Decoding key: 1435 of 2926
# Decoding key: 1436 of 2926
# Decoding key: 1437 of 2926
# Decoding key: 1438 of 2926
# Decoding key: 1439 of 2926
# Decoding key: 1440 of 2926
# Decoding key: 1441 of 2926
# Decoding key: 1442 of 2926
# Decoding key: 1443 of 2926
# Decoding key: 1444 of 2926
# Decoding key: 1445 of 2926
# Decoding key: 1446 of 2926
# Decoding key: 1447 of 2926
# Decoding key: 1448 of 2926
# Decoding key: 1449 of 2926
# Decoding key: 1450 of 2926
# Decoding key: 1451 of 2926
# Decoding key: 1452 of 2926
# Decoding key: 1453 of 2926
# Decoding key: 1454 of 2926
# Decoding key: 1455 of 2926
# Decoding key: 1456 of 2926
# Decoding key: 1457 of 2926
# Decoding key: 1458 of 2926
# Decoding key: 1459 of 2926
# Decoding key: 1460 of 2926
# Decoding key: 1461 of 2926
# Decoding key: 1462 of 2926
# Decoding key: 1463 of 2926
# Decoding key: 1464 of 2926
# Decoding key: 1465 of 2926
# Decoding key: 1466 of 2926
# Decoding key: 1467 of 2926
# Decoding key: 1468 of 2926
# Decoding key: 1469 of 2926
# Decoding key: 1470 of 2926
# Decoding key: 1471 of 2926
# Decoding key: 1472 of 2926
# Decoding key: 1473 of 2926
# Decoding key: 1474 of 2926
# Decoding key: 1475 of 2926
# Decoding key: 1476 of 2926
# Decoding key: 1477 of 2926
# Decoding key: 1478 of 2926
# Decoding key: 1479 of 2926
# Decoding key: 1480 of 2926
# Decoding key: 1481 of 2926
# Decoding key: 1482 of 2926
# Decoding key: 1483 of 2926
# Decoding key: 1484 of 2926
# Decoding key: 1485 of 2926
# Decoding key: 1486 of 2926
# Decoding key: 1487 of 2926
# Decoding key: 1488 of 2926
# Decoding key: 1489 of 2926
# Decoding key: 1490 of 2926
# Decoding key: 1491 of 2926
# Decoding key: 1492 of 2926
# Decoding key: 1493 of 2926
# Decoding key: 1494 of 2926
# Decoding key: 1495 of 2926
# Decoding key: 1496 of 2926
# Decoding key: 1497 of 2926
# Decoding key: 1498 of 2926
# Decoding key: 1499 of 2926
# Decoding key: 1500 of 2926
# Decoding key: 1501 of 2926
# Decoding key: 1502 of 2926
# Decoding key: 1503 of 2926
# Decoding key: 1504 of 2926
# Decoding key: 1505 of 2926
# Decoding key: 1506 of 2926
# Decoding key: 1507 of 2926
# Decoding key: 1508 of 2926
# Decoding key: 1509 of 2926
# Decoding key: 1510 of 2926
# Decoding key: 1511 of 2926
# Decoding key: 1512 of 2926
# Decoding key: 1513 of 2926
# Decoding key: 1514 of 2926
# Decoding key: 1515 of 2926
# Decoding key: 1516 of 2926
# Decoding key: 1517 of 2926
# Decoding key: 1518 of 2926
# Decoding key: 1519 of 2926
# Decoding key: 1520 of 2926
# Decoding key: 1521 of 2926
# Decoding key: 1522 of 2926
# Decoding key: 1523 of 2926
# Decoding key: 1524 of 2926
# Decoding key: 1525 of 2926
# Decoding key: 1526 of 2926
# Decoding key: 1527 of 2926
# Decoding key: 1528 of 2926
# Decoding key: 1529 of 2926
# Decoding key: 1530 of 2926
# Decoding key: 1531 of 2926
# Decoding key: 1532 of 2926
# Decoding key: 1533 of 2926
# Decoding key: 1534 of 2926
# Decoding key: 1535 of 2926
# Decoding key: 1536 of 2926
# Decoding key: 1537 of 2926
# Decoding key: 1538 of 2926
# Decoding key: 1539 of 2926
# Decoding key: 1540 of 2926
# Decoding key: 1541 of 2926
# Decoding key: 1542 of 2926
# Decoding key: 1543 of 2926
# Decoding key: 1544 of 2926
# Decoding key: 1545 of 2926
# Decoding key: 1546 of 2926
# Decoding key: 1547 of 2926
# Decoding key: 1548 of 2926
# Decoding key: 1549 of 2926
# Decoding key: 1550 of 2926
# Decoding key: 1551 of 2926
# Decoding key: 1552 of 2926
# Decoding key: 1553 of 2926
# Decoding key: 1554 of 2926
# Decoding key: 1555 of 2926
# Decoding key: 1556 of 2926
# Decoding key: 1557 of 2926
# Decoding key: 1558 of 2926
# Decoding key: 1559 of 2926
# Decoding key: 1560 of 2926
# Decoding key: 1561 of 2926
# Decoding key: 1562 of 2926
# Decoding key: 1563 of 2926
# Decoding key: 1564 of 2926
# Decoding key: 1565 of 2926
# Decoding key: 1566 of 2926
# Decoding key: 1567 of 2926
# Decoding key: 1568 of 2926
# Decoding key: 1569 of 2926
# Decoding key: 1570 of 2926
# Decoding key: 1571 of 2926
# Decoding key: 1572 of 2926
# Decoding key: 1573 of 2926
# Decoding key: 1574 of 2926
# Decoding key: 1575 of 2926
# Decoding key: 1576 of 2926
# Decoding key: 1577 of 2926
# Decoding key: 1578 of 2926
# Decoding key: 1579 of 2926
# Decoding key: 1580 of 2926
# Decoding key: 1581 of 2926
# Decoding key: 1582 of 2926
# Decoding key: 1583 of 2926
# Decoding key: 1584 of 2926
# Decoding key: 1585 of 2926
# Decoding key: 1586 of 2926
# Decoding key: 1587 of 2926
# Decoding key: 1588 of 2926
# Decoding key: 1589 of 2926
# Decoding key: 1590 of 2926
# Decoding key: 1591 of 2926
# Decoding key: 1592 of 2926
# Decoding key: 1593 of 2926
# Decoding key: 1594 of 2926
# Decoding key: 1595 of 2926
# Decoding key: 1596 of 2926
# Decoding key: 1597 of 2926
# Decoding key: 1598 of 2926
# Decoding key: 1599 of 2926
# Decoding key: 1600 of 2926
# Decoding key: 1601 of 2926
# Decoding key: 1602 of 2926
# Decoding key: 1603 of 2926
# Decoding key: 1604 of 2926
# Decoding key: 1605 of 2926
# Decoding key: 1606 of 2926
# Decoding key: 1607 of 2926
# Decoding key: 1608 of 2926
# Decoding key: 1609 of 2926
# Decoding key: 1610 of 2926
# Decoding key: 1611 of 2926
# Decoding key: 1612 of 2926
# Decoding key: 1613 of 2926
# Decoding key: 1614 of 2926
# Decoding key: 1615 of 2926
# Decoding key: 1616 of 2926
# Decoding key: 1617 of 2926
# Decoding key: 1618 of 2926
# Decoding key: 1619 of 2926
# Decoding key: 1620 of 2926
# Decoding key: 1621 of 2926
# Decoding key: 1622 of 2926
# Decoding key: 1623 of 2926
# Decoding key: 1624 of 2926
# Decoding key: 1625 of 2926
# Decoding key: 1626 of 2926
# Decoding key: 1627 of 2926
# Decoding key: 1628 of 2926
# Decoding key: 1629 of 2926
# Decoding key: 1630 of 2926
# Decoding key: 1631 of 2926
# Decoding key: 1632 of 2926
# Decoding key: 1633 of 2926
# Decoding key: 1634 of 2926
# Decoding key: 1635 of 2926
# Decoding key: 1636 of 2926
# Decoding key: 1637 of 2926
# Decoding key: 1638 of 2926
# Decoding key: 1639 of 2926
# Decoding key: 1640 of 2926
# Decoding key: 1641 of 2926
# Decoding key: 1642 of 2926
# Decoding key: 1643 of 2926
# Decoding key: 1644 of 2926
# Decoding key: 1645 of 2926
# Decoding key: 1646 of 2926
# Decoding key: 1647 of 2926
# Decoding key: 1648 of 2926
# Decoding key: 1649 of 2926
# Decoding key: 1650 of 2926
# Decoding key: 1651 of 2926
# Decoding key: 1652 of 2926
# Decoding key: 1653 of 2926
# Decoding key: 1654 of 2926
# Decoding key: 1655 of 2926
# Decoding key: 1656 of 2926
# Decoding key: 1657 of 2926
# Decoding key: 1658 of 2926
# Decoding key: 1659 of 2926
# Decoding key: 1660 of 2926
# Decoding key: 1661 of 2926
# Decoding key: 1662 of 2926
# Decoding key: 1663 of 2926
# Decoding key: 1664 of 2926
# Decoding key: 1665 of 2926
# Decoding key: 1666 of 2926
# Decoding key: 1667 of 2926
# Decoding key: 1668 of 2926
# Decoding key: 1669 of 2926
# Decoding key: 1670 of 2926
# Decoding key: 1671 of 2926
# Decoding key: 1672 of 2926
# Decoding key: 1673 of 2926
# Decoding key: 1674 of 2926
# Decoding key: 1675 of 2926
# Decoding key: 1676 of 2926
# Decoding key: 1677 of 2926
# Decoding key: 1678 of 2926
# Decoding key: 1679 of 2926
# Decoding key: 1680 of 2926
# Decoding key: 1681 of 2926
# Decoding key: 1682 of 2926
# Decoding key: 1683 of 2926
# Decoding key: 1684 of 2926
# Decoding key: 1685 of 2926
# Decoding key: 1686 of 2926
# Decoding key: 1687 of 2926
# Decoding key: 1688 of 2926
# Decoding key: 1689 of 2926
# Decoding key: 1690 of 2926
# Decoding key: 1691 of 2926
# Decoding key: 1692 of 2926
# Decoding key: 1693 of 2926
# Decoding key: 1694 of 2926
# Decoding key: 1695 of 2926
# Decoding key: 1696 of 2926
# Decoding key: 1697 of 2926
# Decoding key: 1698 of 2926
# Decoding key: 1699 of 2926
# Decoding key: 1700 of 2926
# Decoding key: 1701 of 2926
# Decoding key: 1702 of 2926
# Decoding key: 1703 of 2926
# Decoding key: 1704 of 2926
# Decoding key: 1705 of 2926
# Decoding key: 1706 of 2926
# Decoding key: 1707 of 2926
# Decoding key: 1708 of 2926
# Decoding key: 1709 of 2926
# Decoding key: 1710 of 2926
# Decoding key: 1711 of 2926
# Decoding key: 1712 of 2926
# Decoding key: 1713 of 2926
# Decoding key: 1714 of 2926
# Decoding key: 1715 of 2926
# Decoding key: 1716 of 2926
# Decoding key: 1717 of 2926
# Decoding key: 1718 of 2926
# Decoding key: 1719 of 2926
# Decoding key: 1720 of 2926
# Decoding key: 1721 of 2926
# Decoding key: 1722 of 2926
# Decoding key: 1723 of 2926
# Decoding key: 1724 of 2926
# Decoding key: 1725 of 2926
# Decoding key: 1726 of 2926
# Decoding key: 1727 of 2926
# Decoding key: 1728 of 2926
# Decoding key: 1729 of 2926
# Decoding key: 1730 of 2926
# Decoding key: 1731 of 2926
# Decoding key: 1732 of 2926
# Decoding key: 1733 of 2926
# Decoding key: 1734 of 2926
# Decoding key: 1735 of 2926
# Decoding key: 1736 of 2926
# Decoding key: 1737 of 2926
# Decoding key: 1738 of 2926
# Decoding key: 1739 of 2926
# Decoding key: 1740 of 2926
# Decoding key: 1741 of 2926
# Decoding key: 1742 of 2926
# Decoding key: 1743 of 2926
# Decoding key: 1744 of 2926
# Decoding key: 1745 of 2926
# Decoding key: 1746 of 2926
# Decoding key: 1747 of 2926
# Decoding key: 1748 of 2926
# Decoding key: 1749 of 2926
# Decoding key: 1750 of 2926
# Decoding key: 1751 of 2926
# Decoding key: 1752 of 2926
# Decoding key: 1753 of 2926
# Decoding key: 1754 of 2926
# Decoding key: 1755 of 2926
# Decoding key: 1756 of 2926
# Decoding key: 1757 of 2926
# Decoding key: 1758 of 2926
# Decoding key: 1759 of 2926
# Decoding key: 1760 of 2926
# Decoding key: 1761 of 2926
# Decoding key: 1762 of 2926
# Decoding key: 1763 of 2926
# Decoding key: 1764 of 2926
# Decoding key: 1765 of 2926
# Decoding key: 1766 of 2926
# Decoding key: 1767 of 2926
# Decoding key: 1768 of 2926
# Decoding key: 1769 of 2926
# Decoding key: 1770 of 2926
# Decoding key: 1771 of 2926
# Decoding key: 1772 of 2926
# Decoding key: 1773 of 2926
# Decoding key: 1774 of 2926
# Decoding key: 1775 of 2926
# Decoding key: 1776 of 2926
# Decoding key: 1777 of 2926
# Decoding key: 1778 of 2926
# Decoding key: 1779 of 2926
# Decoding key: 1780 of 2926
# Decoding key: 1781 of 2926
# Decoding key: 1782 of 2926
# Decoding key: 1783 of 2926
# Decoding key: 1784 of 2926
# Decoding key: 1785 of 2926
# Decoding key: 1786 of 2926
# Decoding key: 1787 of 2926
# Decoding key: 1788 of 2926
# Decoding key: 1789 of 2926
# Decoding key: 1790 of 2926
# Decoding key: 1791 of 2926
# Decoding key: 1792 of 2926
# Decoding key: 1793 of 2926
# Decoding key: 1794 of 2926
# Decoding key: 1795 of 2926
# Decoding key: 1796 of 2926
# Decoding key: 1797 of 2926
# Decoding key: 1798 of 2926
# Decoding key: 1799 of 2926
# Decoding key: 1800 of 2926
# Decoding key: 1801 of 2926
# Decoding key: 1802 of 2926
# Decoding key: 1803 of 2926
# Decoding key: 1804 of 2926
# Decoding key: 1805 of 2926
# Decoding key: 1806 of 2926
# Decoding key: 1807 of 2926
# Decoding key: 1808 of 2926
# Decoding key: 1809 of 2926
# Decoding key: 1810 of 2926
# Decoding key: 1811 of 2926
# Decoding key: 1812 of 2926
# Decoding key: 1813 of 2926
# Decoding key: 1814 of 2926
# Decoding key: 1815 of 2926
# Decoding key: 1816 of 2926
# Decoding key: 1817 of 2926
# Decoding key: 1818 of 2926
# Decoding key: 1819 of 2926
# Decoding key: 1820 of 2926
# Decoding key: 1821 of 2926
# Decoding key: 1822 of 2926
# Decoding key: 1823 of 2926
# Decoding key: 1824 of 2926
# Decoding key: 1825 of 2926
# Decoding key: 1826 of 2926
# Decoding key: 1827 of 2926
# Decoding key: 1828 of 2926
# Decoding key: 1829 of 2926
# Decoding key: 1830 of 2926
# Decoding key: 1831 of 2926
# Decoding key: 1832 of 2926
# Decoding key: 1833 of 2926
# Decoding key: 1834 of 2926
# Decoding key: 1835 of 2926
# Decoding key: 1836 of 2926
# Decoding key: 1837 of 2926
# Decoding key: 1838 of 2926
# Decoding key: 1839 of 2926
# Decoding key: 1840 of 2926
# Decoding key: 1841 of 2926
# Decoding key: 1842 of 2926
# Decoding key: 1843 of 2926
# Decoding key: 1844 of 2926
# Decoding key: 1845 of 2926
# Decoding key: 1846 of 2926
# Decoding key: 1847 of 2926
# Decoding key: 1848 of 2926
# Decoding key: 1849 of 2926
# Decoding key: 1850 of 2926
# Decoding key: 1851 of 2926
# Decoding key: 1852 of 2926
# Decoding key: 1853 of 2926
# Decoding key: 1854 of 2926
# Decoding key: 1855 of 2926
# Decoding key: 1856 of 2926
# Decoding key: 1857 of 2926
# Decoding key: 1858 of 2926
# Decoding key: 1859 of 2926
# Decoding key: 1860 of 2926
# Decoding key: 1861 of 2926
# Decoding key: 1862 of 2926
# Decoding key: 1863 of 2926
# Decoding key: 1864 of 2926
# Decoding key: 1865 of 2926
# Decoding key: 1866 of 2926
# Decoding key: 1867 of 2926
# Decoding key: 1868 of 2926
# Decoding key: 1869 of 2926
# Decoding key: 1870 of 2926
# Decoding key: 1871 of 2926
# Decoding key: 1872 of 2926
# Decoding key: 1873 of 2926
# Decoding key: 1874 of 2926
# Decoding key: 1875 of 2926
# Decoding key: 1876 of 2926
# Decoding key: 1877 of 2926
# Decoding key: 1878 of 2926
# Decoding key: 1879 of 2926
# Decoding key: 1880 of 2926
# Decoding key: 1881 of 2926
# Decoding key: 1882 of 2926
# Decoding key: 1883 of 2926
# Decoding key: 1884 of 2926
# Decoding key: 1885 of 2926
# Decoding key: 1886 of 2926
# Decoding key: 1887 of 2926
# Decoding key: 1888 of 2926
# Decoding key: 1889 of 2926
# Decoding key: 1890 of 2926
# Decoding key: 1891 of 2926
# Decoding key: 1892 of 2926
# Decoding key: 1893 of 2926
# Decoding key: 1894 of 2926
# Decoding key: 1895 of 2926
# Decoding key: 1896 of 2926
# Decoding key: 1897 of 2926
# Decoding key: 1898 of 2926
# Decoding key: 1899 of 2926
# Decoding key: 1900 of 2926
# Decoding key: 1901 of 2926
# Decoding key: 1902 of 2926
# Decoding key: 1903 of 2926
# Decoding key: 1904 of 2926
# Decoding key: 1905 of 2926
# Decoding key: 1906 of 2926
# Decoding key: 1907 of 2926
# Decoding key: 1908 of 2926
# Decoding key: 1909 of 2926
# Decoding key: 1910 of 2926
# Decoding key: 1911 of 2926
# Decoding key: 1912 of 2926
# Decoding key: 1913 of 2926
# Decoding key: 1914 of 2926
# Decoding key: 1915 of 2926
# Decoding key: 1916 of 2926
# Decoding key: 1917 of 2926
# Decoding key: 1918 of 2926
# Decoding key: 1919 of 2926
# Decoding key: 1920 of 2926
# Decoding key: 1921 of 2926
# Decoding key: 1922 of 2926
# Decoding key: 1923 of 2926
# Decoding key: 1924 of 2926
# Decoding key: 1925 of 2926
# Decoding key: 1926 of 2926
# Decoding key: 1927 of 2926
# Decoding key: 1928 of 2926
# Decoding key: 1929 of 2926
# Decoding key: 1930 of 2926
# Decoding key: 1931 of 2926
# Decoding key: 1932 of 2926
# Decoding key: 1933 of 2926
# Decoding key: 1934 of 2926
# Decoding key: 1935 of 2926
# Decoding key: 1936 of 2926
# Decoding key: 1937 of 2926
# Decoding key: 1938 of 2926
# Decoding key: 1939 of 2926
# Decoding key: 1940 of 2926
# Decoding key: 1941 of 2926
# Decoding key: 1942 of 2926
# Decoding key: 1943 of 2926
# Decoding key: 1944 of 2926
# Decoding key: 1945 of 2926
# Decoding key: 1946 of 2926
# Decoding key: 1947 of 2926
# Decoding key: 1948 of 2926
# Decoding key: 1949 of 2926
# Decoding key: 1950 of 2926
# Decoding key: 1951 of 2926
# Decoding key: 1952 of 2926
# Decoding key: 1953 of 2926
# Decoding key: 1954 of 2926
# Decoding key: 1955 of 2926
# Decoding key: 1956 of 2926
# Decoding key: 1957 of 2926
# Decoding key: 1958 of 2926
# Decoding key: 1959 of 2926
# Decoding key: 1960 of 2926
# Decoding key: 1961 of 2926
# Decoding key: 1962 of 2926
# Decoding key: 1963 of 2926
# Decoding key: 1964 of 2926
# Decoding key: 1965 of 2926
# Decoding key: 1966 of 2926
# Decoding key: 1967 of 2926
# Decoding key: 1968 of 2926
# Decoding key: 1969 of 2926
# Decoding key: 1970 of 2926
# Decoding key: 1971 of 2926
# Decoding key: 1972 of 2926
# Decoding key: 1973 of 2926
# Decoding key: 1974 of 2926
# Decoding key: 1975 of 2926
# Decoding key: 1976 of 2926
# Decoding key: 1977 of 2926
# Decoding key: 1978 of 2926
# Decoding key: 1979 of 2926
# Decoding key: 1980 of 2926
# Decoding key: 1981 of 2926
# Decoding key: 1982 of 2926
# Decoding key: 1983 of 2926
# Decoding key: 1984 of 2926
# Decoding key: 1985 of 2926
# Decoding key: 1986 of 2926
# Decoding key: 1987 of 2926
# Decoding key: 1988 of 2926
# Decoding key: 1989 of 2926
# Decoding key: 1990 of 2926
# Decoding key: 1991 of 2926
# Decoding key: 1992 of 2926
# Decoding key: 1993 of 2926
# Decoding key: 1994 of 2926
# Decoding key: 1995 of 2926
# Decoding key: 1996 of 2926
# Decoding key: 1997 of 2926
# Decoding key: 1998 of 2926
# Decoding key: 1999 of 2926
# Decoding key: 2000 of 2926
# Decoding key: 2001 of 2926
# Decoding key: 2002 of 2926
# Decoding key: 2003 of 2926
# Decoding key: 2004 of 2926
# Decoding key: 2005 of 2926
# Decoding key: 2006 of 2926
# Decoding key: 2007 of 2926
# Decoding key: 2008 of 2926
# Decoding key: 2009 of 2926
# Decoding key: 2010 of 2926
# Decoding key: 2011 of 2926
# Decoding key: 2012 of 2926
# Decoding key: 2013 of 2926
# Decoding key: 2014 of 2926
# Decoding key: 2015 of 2926
# Decoding key: 2016 of 2926
# Decoding key: 2017 of 2926
# Decoding key: 2018 of 2926
# Decoding key: 2019 of 2926
# Decoding key: 2020 of 2926
# Decoding key: 2021 of 2926
# Decoding key: 2022 of 2926
# Decoding key: 2023 of 2926
# Decoding key: 2024 of 2926
# Decoding key: 2025 of 2926
# Decoding key: 2026 of 2926
# Decoding key: 2027 of 2926
# Decoding key: 2028 of 2926
# Decoding key: 2029 of 2926
# Decoding key: 2030 of 2926
# Decoding key: 2031 of 2926
# Decoding key: 2032 of 2926
# Decoding key: 2033 of 2926
# Decoding key: 2034 of 2926
# Decoding key: 2035 of 2926
# Decoding key: 2036 of 2926
# Decoding key: 2037 of 2926
# Decoding key: 2038 of 2926
# Decoding key: 2039 of 2926
# Decoding key: 2040 of 2926
# Decoding key: 2041 of 2926
# Decoding key: 2042 of 2926
# Decoding key: 2043 of 2926
# Decoding key: 2044 of 2926
# Decoding key: 2045 of 2926
# Decoding key: 2046 of 2926
# Decoding key: 2047 of 2926
# Decoding key: 2048 of 2926
# Decoding key: 2049 of 2926
# Decoding key: 2050 of 2926
# Decoding key: 2051 of 2926
# Decoding key: 2052 of 2926
# Decoding key: 2053 of 2926
# Decoding key: 2054 of 2926
# Decoding key: 2055 of 2926
# Decoding key: 2056 of 2926
# Decoding key: 2057 of 2926
# Decoding key: 2058 of 2926
# Decoding key: 2059 of 2926
# Decoding key: 2060 of 2926
# Decoding key: 2061 of 2926
# Decoding key: 2062 of 2926
# Decoding key: 2063 of 2926
# Decoding key: 2064 of 2926
# Decoding key: 2065 of 2926
# Decoding key: 2066 of 2926
# Decoding key: 2067 of 2926
# Decoding key: 2068 of 2926
# Decoding key: 2069 of 2926
# Decoding key: 2070 of 2926
# Decoding key: 2071 of 2926
# Decoding key: 2072 of 2926
# Decoding key: 2073 of 2926
# Decoding key: 2074 of 2926
# Decoding key: 2075 of 2926
# Decoding key: 2076 of 2926
# Decoding key: 2077 of 2926
# Decoding key: 2078 of 2926
# Decoding key: 2079 of 2926
# Decoding key: 2080 of 2926
# Decoding key: 2081 of 2926
# Decoding key: 2082 of 2926
# Decoding key: 2083 of 2926
# Decoding key: 2084 of 2926
# Decoding key: 2085 of 2926
# Decoding key: 2086 of 2926
# Decoding key: 2087 of 2926
# Decoding key: 2088 of 2926
# Decoding key: 2089 of 2926
# Decoding key: 2090 of 2926
# Decoding key: 2091 of 2926
# Decoding key: 2092 of 2926
# Decoding key: 2093 of 2926
# Decoding key: 2094 of 2926
# Decoding key: 2095 of 2926
# Decoding key: 2096 of 2926
# Decoding key: 2097 of 2926
# Decoding key: 2098 of 2926
# Decoding key: 2099 of 2926
# Decoding key: 2100 of 2926
# Decoding key: 2101 of 2926
# Decoding key: 2102 of 2926
# Decoding key: 2103 of 2926
# Decoding key: 2104 of 2926
# Decoding key: 2105 of 2926
# Decoding key: 2106 of 2926
# Decoding key: 2107 of 2926
# Decoding key: 2108 of 2926
# Decoding key: 2109 of 2926
# Decoding key: 2110 of 2926
# Decoding key: 2111 of 2926
# Decoding key: 2112 of 2926
# Decoding key: 2113 of 2926
# Decoding key: 2114 of 2926
# Decoding key: 2115 of 2926
# Decoding key: 2116 of 2926
# Decoding key: 2117 of 2926
# Decoding key: 2118 of 2926
# Decoding key: 2119 of 2926
# Decoding key: 2120 of 2926
# Decoding key: 2121 of 2926
# Decoding key: 2122 of 2926
# Decoding key: 2123 of 2926
# Decoding key: 2124 of 2926
# Decoding key: 2125 of 2926
# Decoding key: 2126 of 2926
# Decoding key: 2127 of 2926
# Decoding key: 2128 of 2926
# Decoding key: 2129 of 2926
# Decoding key: 2130 of 2926
# Decoding key: 2131 of 2926
# Decoding key: 2132 of 2926
# Decoding key: 2133 of 2926
# Decoding key: 2134 of 2926
# Decoding key: 2135 of 2926
# Decoding key: 2136 of 2926
# Decoding key: 2137 of 2926
# Decoding key: 2138 of 2926
# Decoding key: 2139 of 2926
# Decoding key: 2140 of 2926
# Decoding key: 2141 of 2926
# Decoding key: 2142 of 2926
# Decoding key: 2143 of 2926
# Decoding key: 2144 of 2926
# Decoding key: 2145 of 2926
# Decoding key: 2146 of 2926
# Decoding key: 2147 of 2926
# Decoding key: 2148 of 2926
# Decoding key: 2149 of 2926
# Decoding key: 2150 of 2926
# Decoding key: 2151 of 2926
# Decoding key: 2152 of 2926
# Decoding key: 2153 of 2926
# Decoding key: 2154 of 2926
# Decoding key: 2155 of 2926
# Decoding key: 2156 of 2926
# Decoding key: 2157 of 2926
# Decoding key: 2158 of 2926
# Decoding key: 2159 of 2926
# Decoding key: 2160 of 2926
# Decoding key: 2161 of 2926
# Decoding key: 2162 of 2926
# Decoding key: 2163 of 2926
# Decoding key: 2164 of 2926
# Decoding key: 2165 of 2926
# Decoding key: 2166 of 2926
# Decoding key: 2167 of 2926
# Decoding key: 2168 of 2926
# Decoding key: 2169 of 2926
# Decoding key: 2170 of 2926
# Decoding key: 2171 of 2926
# Decoding key: 2172 of 2926
# Decoding key: 2173 of 2926
# Decoding key: 2174 of 2926
# Decoding key: 2175 of 2926
# Decoding key: 2176 of 2926
# Decoding key: 2177 of 2926
# Decoding key: 2178 of 2926
# Decoding key: 2179 of 2926
# Decoding key: 2180 of 2926
# Decoding key: 2181 of 2926
# Decoding key: 2182 of 2926
# Decoding key: 2183 of 2926
# Decoding key: 2184 of 2926
# Decoding key: 2185 of 2926
# Decoding key: 2186 of 2926
# Decoding key: 2187 of 2926
# Decoding key: 2188 of 2926
# Decoding key: 2189 of 2926
# Decoding key: 2190 of 2926
# Decoding key: 2191 of 2926
# Decoding key: 2192 of 2926
# Decoding key: 2193 of 2926
# Decoding key: 2194 of 2926
# Decoding key: 2195 of 2926
# Decoding key: 2196 of 2926
# Decoding key: 2197 of 2926
# Decoding key: 2198 of 2926
# Decoding key: 2199 of 2926
# Decoding key: 2200 of 2926
# Decoding key: 2201 of 2926
# Decoding key: 2202 of 2926
# Decoding key: 2203 of 2926
# Decoding key: 2204 of 2926
# Decoding key: 2205 of 2926
# Decoding key: 2206 of 2926
# Decoding key: 2207 of 2926
# Decoding key: 2208 of 2926
# Decoding key: 2209 of 2926
# Decoding key: 2210 of 2926
# Decoding key: 2211 of 2926
# Decoding key: 2212 of 2926
# Decoding key: 2213 of 2926
# Decoding key: 2214 of 2926
# Decoding key: 2215 of 2926
# Decoding key: 2216 of 2926
# Decoding key: 2217 of 2926
# Decoding key: 2218 of 2926
# Decoding key: 2219 of 2926
# Decoding key: 2220 of 2926
# Decoding key: 2221 of 2926
# Decoding key: 2222 of 2926
# Decoding key: 2223 of 2926
# Decoding key: 2224 of 2926
# Decoding key: 2225 of 2926
# Decoding key: 2226 of 2926
# Decoding key: 2227 of 2926
# Decoding key: 2228 of 2926
# Decoding key: 2229 of 2926
# Decoding key: 2230 of 2926
# Decoding key: 2231 of 2926
# Decoding key: 2232 of 2926
# Decoding key: 2233 of 2926
# Decoding key: 2234 of 2926
# Decoding key: 2235 of 2926
# Decoding key: 2236 of 2926
# Decoding key: 2237 of 2926
# Decoding key: 2238 of 2926
# Decoding key: 2239 of 2926
# Decoding key: 2240 of 2926
# Decoding key: 2241 of 2926
# Decoding key: 2242 of 2926
# Decoding key: 2243 of 2926
# Decoding key: 2244 of 2926
# Decoding key: 2245 of 2926
# Decoding key: 2246 of 2926
# Decoding key: 2247 of 2926
# Decoding key: 2248 of 2926
# Decoding key: 2249 of 2926
# Decoding key: 2250 of 2926
# Decoding key: 2251 of 2926
# Decoding key: 2252 of 2926
# Decoding key: 2253 of 2926
# Decoding key: 2254 of 2926
# Decoding key: 2255 of 2926
# Decoding key: 2256 of 2926
# Decoding key: 2257 of 2926
# Decoding key: 2258 of 2926
# Decoding key: 2259 of 2926
# Decoding key: 2260 of 2926
# Decoding key: 2261 of 2926
# Decoding key: 2262 of 2926
# Decoding key: 2263 of 2926
# Decoding key: 2264 of 2926
# Decoding key: 2265 of 2926
# Decoding key: 2266 of 2926
# Decoding key: 2267 of 2926
# Decoding key: 2268 of 2926
# Decoding key: 2269 of 2926
# Decoding key: 2270 of 2926
# Decoding key: 2271 of 2926
# Decoding key: 2272 of 2926
# Decoding key: 2273 of 2926
# Decoding key: 2274 of 2926
# Decoding key: 2275 of 2926
# Decoding key: 2276 of 2926
# Decoding key: 2277 of 2926
# Decoding key: 2278 of 2926
# Decoding key: 2279 of 2926
# Decoding key: 2280 of 2926
# Decoding key: 2281 of 2926
# Decoding key: 2282 of 2926
# Decoding key: 2283 of 2926
# Decoding key: 2284 of 2926
# Decoding key: 2285 of 2926
# Decoding key: 2286 of 2926
# Decoding key: 2287 of 2926
# Decoding key: 2288 of 2926
# Decoding key: 2289 of 2926
# Decoding key: 2290 of 2926
# Decoding key: 2291 of 2926
# Decoding key: 2292 of 2926
# Decoding key: 2293 of 2926
# Decoding key: 2294 of 2926
# Decoding key: 2295 of 2926
# Decoding key: 2296 of 2926
# Decoding key: 2297 of 2926
# Decoding key: 2298 of 2926
# Decoding key: 2299 of 2926
# Decoding key: 2300 of 2926
# Decoding key: 2301 of 2926
# Decoding key: 2302 of 2926
# Decoding key: 2303 of 2926
# Decoding key: 2304 of 2926
# Decoding key: 2305 of 2926
# Decoding key: 2306 of 2926
# Decoding key: 2307 of 2926
# Decoding key: 2308 of 2926
# Decoding key: 2309 of 2926
# Decoding key: 2310 of 2926
# Decoding key: 2311 of 2926
# Decoding key: 2312 of 2926
# Decoding key: 2313 of 2926
# Decoding key: 2314 of 2926
# Decoding key: 2315 of 2926
# Decoding key: 2316 of 2926
# Decoding key: 2317 of 2926
# Decoding key: 2318 of 2926
# Decoding key: 2319 of 2926
# Decoding key: 2320 of 2926
# Decoding key: 2321 of 2926
# Decoding key: 2322 of 2926
# Decoding key: 2323 of 2926
# Decoding key: 2324 of 2926
# Decoding key: 2325 of 2926
# Decoding key: 2326 of 2926
# Decoding key: 2327 of 2926
# Decoding key: 2328 of 2926
# Decoding key: 2329 of 2926
# Decoding key: 2330 of 2926
# Decoding key: 2331 of 2926
# Decoding key: 2332 of 2926
# Decoding key: 2333 of 2926
# Decoding key: 2334 of 2926
# Decoding key: 2335 of 2926
# Decoding key: 2336 of 2926
# Decoding key: 2337 of 2926
# Decoding key: 2338 of 2926
# Decoding key: 2339 of 2926
# Decoding key: 2340 of 2926
# Decoding key: 2341 of 2926
# Decoding key: 2342 of 2926
# Decoding key: 2343 of 2926
# Decoding key: 2344 of 2926
# Decoding key: 2345 of 2926
# Decoding key: 2346 of 2926
# Decoding key: 2347 of 2926
# Decoding key: 2348 of 2926
# Decoding key: 2349 of 2926
# Decoding key: 2350 of 2926
# Decoding key: 2351 of 2926
# Decoding key: 2352 of 2926
# Decoding key: 2353 of 2926
# Decoding key: 2354 of 2926
# Decoding key: 2355 of 2926
# Decoding key: 2356 of 2926
# Decoding key: 2357 of 2926
# Decoding key: 2358 of 2926
# Decoding key: 2359 of 2926
# Decoding key: 2360 of 2926
# Decoding key: 2361 of 2926
# Decoding key: 2362 of 2926
# Decoding key: 2363 of 2926
# Decoding key: 2364 of 2926
# Decoding key: 2365 of 2926
# Decoding key: 2366 of 2926
# Decoding key: 2367 of 2926
# Decoding key: 2368 of 2926
# Decoding key: 2369 of 2926
# Decoding key: 2370 of 2926
# Decoding key: 2371 of 2926
# Decoding key: 2372 of 2926
# Decoding key: 2373 of 2926
# Decoding key: 2374 of 2926
# Decoding key: 2375 of 2926
# Decoding key: 2376 of 2926
# Decoding key: 2377 of 2926
# Decoding key: 2378 of 2926
# Decoding key: 2379 of 2926
# Decoding key: 2380 of 2926
# Decoding key: 2381 of 2926
# Decoding key: 2382 of 2926
# Decoding key: 2383 of 2926
# Decoding key: 2384 of 2926
# Decoding key: 2385 of 2926
# Decoding key: 2386 of 2926
# Decoding key: 2387 of 2926
# Decoding key: 2388 of 2926
# Decoding key: 2389 of 2926
# Decoding key: 2390 of 2926
# Decoding key: 2391 of 2926
# Decoding key: 2392 of 2926
# Decoding key: 2393 of 2926
# Decoding key: 2394 of 2926
# Decoding key: 2395 of 2926
# Decoding key: 2396 of 2926
# Decoding key: 2397 of 2926
# Decoding key: 2398 of 2926
# Decoding key: 2399 of 2926
# Decoding key: 2400 of 2926
# Decoding key: 2401 of 2926
# Decoding key: 2402 of 2926
# Decoding key: 2403 of 2926
# Decoding key: 2404 of 2926
# Decoding key: 2405 of 2926
# Decoding key: 2406 of 2926
# Decoding key: 2407 of 2926
# Decoding key: 2408 of 2926
# Decoding key: 2409 of 2926
# Decoding key: 2410 of 2926
# Decoding key: 2411 of 2926
# Decoding key: 2412 of 2926
# Decoding key: 2413 of 2926
# Decoding key: 2414 of 2926
# Decoding key: 2415 of 2926
# Decoding key: 2416 of 2926
# Decoding key: 2417 of 2926
# Decoding key: 2418 of 2926
# Decoding key: 2419 of 2926
# Decoding key: 2420 of 2926
# Decoding key: 2421 of 2926
# Decoding key: 2422 of 2926
# Decoding key: 2423 of 2926
# Decoding key: 2424 of 2926
# Decoding key: 2425 of 2926
# Decoding key: 2426 of 2926
# Decoding key: 2427 of 2926
# Decoding key: 2428 of 2926
# Decoding key: 2429 of 2926
# Decoding key: 2430 of 2926
# Decoding key: 2431 of 2926
# Decoding key: 2432 of 2926
# Decoding key: 2433 of 2926
# Decoding key: 2434 of 2926
# Decoding key: 2435 of 2926
# Decoding key: 2436 of 2926
# Decoding key: 2437 of 2926
# Decoding key: 2438 of 2926
# Decoding key: 2439 of 2926
# Decoding key: 2440 of 2926
# Decoding key: 2441 of 2926
# Decoding key: 2442 of 2926
# Decoding key: 2443 of 2926
# Decoding key: 2444 of 2926
# Decoding key: 2445 of 2926
# Decoding key: 2446 of 2926
# Decoding key: 2447 of 2926
# Decoding key: 2448 of 2926
# Decoding key: 2449 of 2926
# Decoding key: 2450 of 2926
# Decoding key: 2451 of 2926
# Decoding key: 2452 of 2926
# Decoding key: 2453 of 2926
# Decoding key: 2454 of 2926
# Decoding key: 2455 of 2926
# Decoding key: 2456 of 2926
# Decoding key: 2457 of 2926
# Decoding key: 2458 of 2926
# Decoding key: 2459 of 2926
# Decoding key: 2460 of 2926
# Decoding key: 2461 of 2926
# Decoding key: 2462 of 2926
# Decoding key: 2463 of 2926
# Decoding key: 2464 of 2926
# Decoding key: 2465 of 2926
# Decoding key: 2466 of 2926
# Decoding key: 2467 of 2926
# Decoding key: 2468 of 2926
# Decoding key: 2469 of 2926
# Decoding key: 2470 of 2926
# Decoding key: 2471 of 2926
# Decoding key: 2472 of 2926
# Decoding key: 2473 of 2926
# Decoding key: 2474 of 2926
# Decoding key: 2475 of 2926
# Decoding key: 2476 of 2926
# Decoding key: 2477 of 2926
# Decoding key: 2478 of 2926
# Decoding key: 2479 of 2926
# Decoding key: 2480 of 2926
# Decoding key: 2481 of 2926
# Decoding key: 2482 of 2926
# Decoding key: 2483 of 2926
# Decoding key: 2484 of 2926
# Decoding key: 2485 of 2926
# Decoding key: 2486 of 2926
# Decoding key: 2487 of 2926
# Decoding key: 2488 of 2926
# Decoding key: 2489 of 2926
# Decoding key: 2490 of 2926
# Decoding key: 2491 of 2926
# Decoding key: 2492 of 2926
# Decoding key: 2493 of 2926
# Decoding key: 2494 of 2926
# Decoding key: 2495 of 2926
# Decoding key: 2496 of 2926
# Decoding key: 2497 of 2926
# Decoding key: 2498 of 2926
# Decoding key: 2499 of 2926
# Decoding key: 2500 of 2926
# Decoding key: 2501 of 2926
# Decoding key: 2502 of 2926
# Decoding key: 2503 of 2926
# Decoding key: 2504 of 2926
# Decoding key: 2505 of 2926
# Decoding key: 2506 of 2926
# Decoding key: 2507 of 2926
# Decoding key: 2508 of 2926
# Decoding key: 2509 of 2926
# Decoding key: 2510 of 2926
# Decoding key: 2511 of 2926
# Decoding key: 2512 of 2926
# Decoding key: 2513 of 2926
# Decoding key: 2514 of 2926
# Decoding key: 2515 of 2926
# Decoding key: 2516 of 2926
# Decoding key: 2517 of 2926
# Decoding key: 2518 of 2926
# Decoding key: 2519 of 2926
# Decoding key: 2520 of 2926
# Decoding key: 2521 of 2926
# Decoding key: 2522 of 2926
# Decoding key: 2523 of 2926
# Decoding key: 2524 of 2926
# Decoding key: 2525 of 2926
# Decoding key: 2526 of 2926
# Decoding key: 2527 of 2926
# Decoding key: 2528 of 2926
# Decoding key: 2529 of 2926
# Decoding key: 2530 of 2926
# Decoding key: 2531 of 2926
# Decoding key: 2532 of 2926
# Decoding key: 2533 of 2926
# Decoding key: 2534 of 2926
# Decoding key: 2535 of 2926
# Decoding key: 2536 of 2926
# Decoding key: 2537 of 2926
# Decoding key: 2538 of 2926
# Decoding key: 2539 of 2926
# Decoding key: 2540 of 2926
# Decoding key: 2541 of 2926
# Decoding key: 2542 of 2926
# Decoding key: 2543 of 2926
# Decoding key: 2544 of 2926
# Decoding key: 2545 of 2926
# Decoding key: 2546 of 2926
# Decoding key: 2547 of 2926
# Decoding key: 2548 of 2926
# Decoding key: 2549 of 2926
# Decoding key: 2550 of 2926
# Decoding key: 2551 of 2926
# Decoding key: 2552 of 2926
# Decoding key: 2553 of 2926
# Decoding key: 2554 of 2926
# Decoding key: 2555 of 2926
# Decoding key: 2556 of 2926
# Decoding key: 2557 of 2926
# Decoding key: 2558 of 2926
# Decoding key: 2559 of 2926
# Decoding key: 2560 of 2926
# Decoding key: 2561 of 2926
# Decoding key: 2562 of 2926
# Decoding key: 2563 of 2926
# Decoding key: 2564 of 2926
# Decoding key: 2565 of 2926
# Decoding key: 2566 of 2926
# Decoding key: 2567 of 2926
# Decoding key: 2568 of 2926
# Decoding key: 2569 of 2926
# Decoding key: 2570 of 2926
# Decoding key: 2571 of 2926
# Decoding key: 2572 of 2926
# Decoding key: 2573 of 2926
# Decoding key: 2574 of 2926
# Decoding key: 2575 of 2926
# Decoding key: 2576 of 2926
# Decoding key: 2577 of 2926
# Decoding key: 2578 of 2926
# Decoding key: 2579 of 2926
# Decoding key: 2580 of 2926
# Decoding key: 2581 of 2926
# Decoding key: 2582 of 2926
# Decoding key: 2583 of 2926
# Decoding key: 2584 of 2926
# Decoding key: 2585 of 2926
# Decoding key: 2586 of 2926
# Decoding key: 2587 of 2926
# Decoding key: 2588 of 2926
# Decoding key: 2589 of 2926
# Decoding key: 2590 of 2926
# Decoding key: 2591 of 2926
# Decoding key: 2592 of 2926
# Decoding key: 2593 of 2926
# Decoding key: 2594 of 2926
# Decoding key: 2595 of 2926
# Decoding key: 2596 of 2926
# Decoding key: 2597 of 2926
# Decoding key: 2598 of 2926
# Decoding key: 2599 of 2926
# Decoding key: 2600 of 2926
# Decoding key: 2601 of 2926
# Decoding key: 2602 of 2926
# Decoding key: 2603 of 2926
# Decoding key: 2604 of 2926
# Decoding key: 2605 of 2926
# Decoding key: 2606 of 2926
# Decoding key: 2607 of 2926
# Decoding key: 2608 of 2926
# Decoding key: 2609 of 2926
# Decoding key: 2610 of 2926
# Decoding key: 2611 of 2926
# Decoding key: 2612 of 2926
# Decoding key: 2613 of 2926
# Decoding key: 2614 of 2926
# Decoding key: 2615 of 2926
# Decoding key: 2616 of 2926
# Decoding key: 2617 of 2926
# Decoding key: 2618 of 2926
# Decoding key: 2619 of 2926
# Decoding key: 2620 of 2926
# Decoding key: 2621 of 2926
# Decoding key: 2622 of 2926
# Decoding key: 2623 of 2926
# Decoding key: 2624 of 2926
# Decoding key: 2625 of 2926
# Decoding key: 2626 of 2926
# Decoding key: 2627 of 2926
# Decoding key: 2628 of 2926
# Decoding key: 2629 of 2926
# Decoding key: 2630 of 2926
# Decoding key: 2631 of 2926
# Decoding key: 2632 of 2926
# Decoding key: 2633 of 2926
# Decoding key: 2634 of 2926
# Decoding key: 2635 of 2926
# Decoding key: 2636 of 2926
# ...
# Decoding key: 2336 of 2926
# Decoding key: 2337 of 2926
# Decoding key: 2338 of 2926
# Decoding key: 2339 of 2926
# Decoding key: 2340 of 2926
# Decoding key: 2341 of 2926
# Decoding key: 2342 of 2926
# Decoding key: 2343 of 2926
# Decoding key: 2344 of 2926
# Decoding key: 2345 of 2926
# Decoding key: 2346 of 2926
# Decoding key: 2347 of 2926
# Decoding key: 2348 of 2926
# Decoding key: 2349 of 2926
# Decoding key: 2350 of 2926
# Decoding key: 2351 of 2926
# Decoding key: 2352 of 2926
# Decoding key: 2353 of 2926
# Decoding key: 2354 of 2926
# Decoding key: 2355 of 2926
# Decoding key: 2356 of 2926
# Decoding key: 2357 of 2926
# Decoding key: 2358 of 2926
# Decoding key: 2359 of 2926
# Decoding key: 2360 of 2926
# Decoding key: 2361 of 2926
# Decoding key: 2362 of 2926
# Decoding key: 2363 of 2926
# Decoding key: 2364 of 2926
# Decoding key: 2365 of 2926
# Decoding key: 2366 of 2926
# Decoding key: 2367 of 2926
# Decoding key: 2368 of 2926
# Decoding key: 2369 of 2926
# Decoding key: 2370 of 2926
# Decoding key: 2371 of 2926
# Decoding key: 2372 of 2926
# Decoding key: 2373 of 2926
# Decoding key: 2374 of 2926
# Decoding key: 2375 of 2926
# Decoding key: 2376 of 2926
# Decoding key: 2377 of 2926
# Decoding key: 2378 of 2926
# Decoding key: 2379 of 2926
# Decoding key: 2380 of 2926
# Decoding key: 2381 of 2926
# Decoding key: 2382 of 2926
# Decoding key: 2383 of 2926
# Decoding key: 2384 of 2926
# Decoding key: 2385 of 2926
# Decoding key: 2386 of 2926
# Decoding key: 2387 of 2926
# Decoding key: 2388 of 2926
# Decoding key: 2389 of 2926
# Decoding key: 2390 of 2926
# Decoding key: 2391 of 2926
# Decoding key: 2392 of 2926
# Decoding key: 2393 of 2926
# Decoding key: 2394 of 2926
# Decoding key: 2395 of 2926
# Decoding key: 2396 of 2926
# Decoding key: 2397 of 2926
# Decoding key: 2398 of 2926
# Decoding key: 2399 of 2926
# Decoding key: 2400 of 2926
# Decoding key: 2401 of 2926
# Decoding key: 2402 of 2926
# Decoding key: 2403 of 2926
# Decoding key: 2404 of 2926
# Decoding key: 2405 of 2926
# Decoding key: 2406 of 2926
# Decoding key: 2407 of 2926
# Decoding key: 2408 of 2926
# Decoding key: 2409 of 2926
# Decoding key: 2410 of 2926
# Decoding key: 2411 of 2926
# Decoding key: 2412 of 2926
# Decoding key: 2413 of 2926
# Decoding key: 2414 of 2926
# Decoding key: 2415 of 2926
# Decoding key: 2416 of 2926
# Decoding key: 2417 of 2926
# Decoding key: 2418 of 2926
# Decoding key: 2419 of 2926
# Decoding key: 2420 of 2926
# Decoding key: 2421 of 2926
# Decoding key: 2422 of 2926
# Decoding key: 2423 of 2926
# Decoding key: 2424 of 2926
# Decoding key: 2425 of 2926
# Decoding key: 2426 of 2926
# Decoding key: 2427 of 2926
# Decoding key: 2428 of 2926
# Decoding key: 2429 of 2926
# Decoding key: 2430 of 2926
# Decoding key: 2431 of 2926
# Decoding key: 2432 of 2926
# Decoding key: 2433 of 2926
# Decoding key: 2434 of 2926
# Decoding key: 2435 of 2926
# Decoding key: 2436 of 2926
# Decoding key: 2437 of 2926
# Decoding key: 2438 of 2926
# Decoding key: 2439 of 2926
# Decoding key: 2440 of 2926
# Decoding key: 2441 of 2926
# Decoding key: 2442 of 2926
# Decoding key: 2443 of 2926
# Decoding key: 2444 of 2926
# Decoding key: 2445 of 2926
# Decoding key: 2446 of 2926
# Decoding key: 2447 of 2926
# Decoding key: 2448 of 2926
# Decoding key: 2449 of 2926
# Decoding key: 2450 of 2926
# Decoding key: 2451 of 2926
# Decoding key: 2452 of 2926
# Decoding key: 2453 of 2926
# Decoding key: 2454 of 2926
# Decoding key: 2455 of 2926
# Decoding key: 2456 of 2926
# Decoding key: 2457 of 2926
# Decoding key: 2458 of 2926
# Decoding key: 2459 of 2926
# Decoding key: 2460 of 2926
# Decoding key: 2461 of 2926
# Decoding key: 2462 of 2926
# Decoding key: 2463 of 2926
# Decoding key: 2464 of 2926
# Decoding key: 2465 of 2926
# Decoding key: 2466 of 2926
# Decoding key: 2467 of 2926
# Decoding key: 2468 of 2926
# Decoding key: 2469 of 2926
# Decoding key: 2470 of 2926
# Decoding key: 2471 of 2926
# Decoding key: 2472 of 2926
# Decoding key: 2473 of 2926
# Decoding key: 2474 of 2926
# Decoding key: 2475 of 2926
# Decoding key: 2476 of 2926
# Decoding key: 2477 of 2926
# Decoding key: 2478 of 2926
# Decoding key: 2479 of 2926
# Decoding key: 2480 of 2926
# Decoding key: 2481 of 2926
# Decoding key: 2482 of 2926
# Decoding key: 2483 of 2926
# Decoding key: 2484 of 2926
# Decoding key: 2485 of 2926
# Decoding key: 2486 of 2926
# Decoding key: 2487 of 2926
# Decoding key: 2488 of 2926
# Decoding key: 2489 of 2926
# Decoding key: 2490 of 2926
# Decoding key: 2491 of 2926
# Decoding key: 2492 of 2926
# Decoding key: 2493 of 2926
# Decoding key: 2494 of 2926
# Decoding key: 2495 of 2926
# Decoding key: 2496 of 2926
# Decoding key: 2497 of 2926
# Decoding key: 2498 of 2926
# Decoding key: 2499 of 2926
# Decoding key: 2500 of 2926
# Decoding key: 2501 of 2926
# Decoding key: 2502 of 2926
# Decoding key: 2503 of 2926
# Decoding key: 2504 of 2926
# Decoding key: 2505 of 2926
# Decoding key: 2506 of 2926
# Decoding key: 2507 of 2926
# Decoding key: 2508 of 2926
# Decoding key: 2509 of 2926
# Decoding key: 2510 of 2926
# Decoding key: 2511 of 2926
# Decoding key: 2512 of 2926
# Decoding key: 2513 of 2926
# Decoding key: 2514 of 2926
# Decoding key: 2515 of 2926
# Decoding key: 2516 of 2926
# Decoding key: 2517 of 2926
# Decoding key: 2518 of 2926
# Decoding key: 2519 of 2926
# Decoding key: 2520 of 2926
# Decoding key: 2521 of 2926
# Decoding key: 2522 of 2926
# Decoding key: 2523 of 2926
# Decoding key: 2524 of 2926
# Decoding key: 2525 of 2926
# Decoding key: 2526 of 2926
# Decoding key: 2527 of 2926
# Decoding key: 2528 of 2926
# Decoding key: 2529 of 2926
# Decoding key: 2530 of 2926
# Decoding key: 2531 of 2926
# Decoding key: 2532 of 2926
# Decoding key: 2533 of 2926
# Decoding key: 2534 of 2926
# Decoding key: 2535 of 2926
# Decoding key: 2536 of 2926
# Decoding key: 2537 of 2926
# Decoding key: 2538 of 2926
# Decoding key: 2539 of 2926
# Decoding key: 2540 of 2926
# Decoding key: 2541 of 2926
# Decoding key: 2542 of 2926
# Decoding key: 2543 of 2926
# Decoding key: 2544 of 2926
# Decoding key: 2545 of 2926
# Decoding key: 2546 of 2926
# Decoding key: 2547 of 2926
# Decoding key: 2548 of 2926
# Decoding key: 2549 of 2926
# Decoding key: 2550 of 2926
# Decoding key: 2551 of 2926
# Decoding key: 2552 of 2926
# Decoding key: 2553 of 2926
# Decoding key: 2554 of 2926
# Decoding key: 2555 of 2926
# Decoding key: 2556 of 2926
# Decoding key: 2557 of 2926
# Decoding key: 2558 of 2926
# Decoding key: 2559 of 2926
# Decoding key: 2560 of 2926
# Decoding key: 2561 of 2926
# Decoding key: 2562 of 2926
# Decoding key: 2563 of 2926
# Decoding key: 2564 of 2926
# Decoding key: 2565 of 2926
# Decoding key: 2566 of 2926
# Decoding key: 2567 of 2926
# Decoding key: 2568 of 2926
# Decoding key: 2569 of 2926
# Decoding key: 2570 of 2926
# Decoding key: 2571 of 2926
# Decoding key: 2572 of 2926
# Decoding key: 2573 of 2926
# Decoding key: 2574 of 2926
# Decoding key: 2575 of 2926
# Decoding key: 2576 of 2926
# Decoding key: 2577 of 2926
# Decoding key: 2578 of 2926
# Decoding key: 2579 of 2926
# Decoding key: 2580 of 2926
# Decoding key: 2581 of 2926
# Decoding key: 2582 of 2926
# Decoding key: 2583 of 2926
# Decoding key: 2584 of 2926
# Decoding key: 2585 of 2926
# Decoding key: 2586 of 2926
# Decoding key: 2587 of 2926
# Decoding key: 2588 of 2926
# Decoding key: 2589 of 2926
# Decoding key: 2590 of 2926
# Decoding key: 2591 of 2926
# Decoding key: 2592 of 2926
# Decoding key: 2593 of 2926
# Decoding key: 2594 of 2926
# Decoding key: 2595 of 2926
# Decoding key: 2596 of 2926
# Decoding key: 2597 of 2926
# Decoding key: 2598 of 2926
# Decoding key: 2599 of 2926
# Decoding key: 2600 of 2926
# Decoding key: 2601 of 2926
# Decoding key: 2602 of 2926
# Decoding key: 2603 of 2926
# Decoding key: 2604 of 2926
# Decoding key: 2605 of 2926
# Decoding key: 2606 of 2926
# Decoding key: 2607 of 2926
# Decoding key: 2608 of 2926
# Decoding key: 2609 of 2926
# Decoding key: 2610 of 2926
# Decoding key: 2611 of 2926
# Decoding key: 2612 of 2926
# Decoding key: 2613 of 2926
# Decoding key: 2614 of 2926
# Decoding key: 2615 of 2926
# Decoding key: 2616 of 2926
# Decoding key: 2617 of 2926
# Decoding key: 2618 of 2926
# Decoding key: 2619 of 2926
# Decoding key: 2620 of 2926
# Decoding key: 2621 of 2926
# Decoding key: 2622 of 2926
# Decoding key: 2623 of 2926
# Decoding key: 2624 of 2926
# Decoding key: 2625 of 2926
# Decoding key: 2626 of 2926
# Decoding key: 2627 of 2926
# Decoding key: 2628 of 2926
# Decoding key: 2629 of 2926
# Decoding key: 2630 of 2926
# Decoding key: 2631 of 2926
# Decoding key: 2632 of 2926
# Decoding key: 2633 of 2926
# Decoding key: 2634 of 2926
# Decoding key: 2635 of 2926
# Decoding key: 2636 of 2926
# Decoding key: 2637 of 2926
# Decoding key: 2638 of 2926
# Decoding key: 2639 of 2926
# Decoding key: 2640 of 2926
# Decoding key: 2641 of 2926
# Decoding key: 2642 of 2926
# Decoding key: 2643 of 2926
# Decoding key: 2644 of 2926
# Decoding key: 2645 of 2926
# Decoding key: 2646 of 2926
# Decoding key: 2647 of 2926
# Decoding key: 2648 of 2926
# Decoding key: 2649 of 2926
# Decoding key: 2650 of 2926
# Decoding key: 2651 of 2926
# Decoding key: 2652 of 2926
# Decoding key: 2653 of 2926
# Decoding key: 2654 of 2926
# Decoding key: 2655 of 2926
# Decoding key: 2656 of 2926
# Decoding key: 2657 of 2926
# Decoding key: 2658 of 2926
# Decoding key: 2659 of 2926
# Decoding key: 2660 of 2926
# Decoding key: 2661 of 2926
# Decoding key: 2662 of 2926
# Decoding key: 2663 of 2926
# Decoding key: 2664 of 2926
# Decoding key: 2665 of 2926
# Decoding key: 2666 of 2926
# Decoding key: 2667 of 2926
# Decoding key: 2668 of 2926
# Decoding key: 2669 of 2926
# Decoding key: 2670 of 2926
# Decoding key: 2671 of 2926
# Decoding key: 2672 of 2926
# Decoding key: 2673 of 2926
# Decoding key: 2674 of 2926
# Decoding key: 2675 of 2926
# Decoding key: 2676 of 2926
# Decoding key: 2677 of 2926
# Decoding key: 2678 of 2926
# Decoding key: 2679 of 2926
# Decoding key: 2680 of 2926
# Decoding key: 2681 of 2926
# Decoding key: 2682 of 2926
# Decoding key: 2683 of 2926
# Decoding key: 2684 of 2926
# Decoding key: 2685 of 2926
# Decoding key: 2686 of 2926
# Decoding key: 2687 of 2926
# Decoding key: 2688 of 2926
# Decoding key: 2689 of 2926
# Decoding key: 2690 of 2926
# Decoding key: 2691 of 2926
# Decoding key: 2692 of 2926
# Decoding key: 2693 of 2926
# Decoding key: 2694 of 2926
# Decoding key: 2695 of 2926
# Decoding key: 2696 of 2926
# Decoding key: 2697 of 2926
# Decoding key: 2698 of 2926
# Decoding key: 2699 of 2926
# Decoding key: 2700 of 2926
# Decoding key: 2701 of 2926
# Decoding key: 2702 of 2926
# Decoding key: 2703 of 2926
# Decoding key: 2704 of 2926
# Decoding key: 2705 of 2926
# Decoding key: 2706 of 2926
# Decoding key: 2707 of 2926
# Decoding key: 2708 of 2926
# Decoding key: 2709 of 2926
# Decoding key: 2710 of 2926
# Decoding key: 2711 of 2926
# Decoding key: 2712 of 2926
# Decoding key: 2713 of 2926
# Decoding key: 2714 of 2926
# Decoding key: 2715 of 2926
# Decoding key: 2716 of 2926
# Decoding key: 2717 of 2926
# Decoding key: 2718 of 2926
# Decoding key: 2719 of 2926
# Decoding key: 2720 of 2926
# Decoding key: 2721 of 2926
# Decoding key: 2722 of 2926
# Decoding key: 2723 of 2926
# Decoding key: 2724 of 2926
# Decoding key: 2725 of 2926
# Decoding key: 2726 of 2926
# Decoding key: 2727 of 2926
# Decoding key: 2728 of 2926
# Decoding key: 2729 of 2926
# Decoding key: 2730 of 2926
# Decoding key: 2731 of 2926
# Decoding key: 2732 of 2926
# Decoding key: 2733 of 2926
# Decoding key: 2734 of 2926
# Decoding key: 2735 of 2926
# Decoding key: 2736 of 2926
# Decoding key: 2737 of 2926
# Decoding key: 2738 of 2926
# Decoding key: 2739 of 2926
# Decoding key: 2740 of 2926
# Decoding key: 2741 of 2926
# Decoding key: 2742 of 2926
# Decoding key: 2743 of 2926
# Decoding key: 2744 of 2926
# Decoding key: 2745 of 2926
# Decoding key: 2746 of 2926
# Decoding key: 2747 of 2926
# Decoding key: 2748 of 2926
# Decoding key: 2749 of 2926
# Decoding key: 2750 of 2926
# Decoding key: 2751 of 2926
# Decoding key: 2752 of 2926
# Decoding key: 2753 of 2926
# Decoding key: 2754 of 2926
# Decoding key: 2755 of 2926
# Decoding key: 2756 of 2926
# Decoding key: 2757 of 2926
# Decoding key: 2758 of 2926
# Decoding key: 2759 of 2926
# Decoding key: 2760 of 2926
# Decoding key: 2761 of 2926
# Decoding key: 2762 of 2926
# Decoding key: 2763 of 2926
# Decoding key: 2764 of 2926
# Decoding key: 2765 of 2926
# Decoding key: 2766 of 2926
# Decoding key: 2767 of 2926
# Decoding key: 2768 of 2926
# Decoding key: 2769 of 2926
# Decoding key: 2770 of 2926
# Decoding key: 2771 of 2926
# Decoding key: 2772 of 2926
# Decoding key: 2773 of 2926
# Decoding key: 2774 of 2926
# Decoding key: 2775 of 2926
# Decoding key: 2776 of 2926
# Decoding key: 2777 of 2926
# Decoding key: 2778 of 2926
# Decoding key: 2779 of 2926
# Decoding key: 2780 of 2926
# Decoding key: 2781 of 2926
# Decoding key: 2782 of 2926
# Decoding key: 2783 of 2926
# Decoding key: 2784 of 2926
# Decoding key: 2785 of 2926
# Decoding key: 2786 of 2926
# Decoding key: 2787 of 2926
# Decoding key: 2788 of 2926
# Decoding key: 2789 of 2926
# Decoding key: 2790 of 2926
# Decoding key: 2791 of 2926
# Decoding key: 2792 of 2926
# Decoding key: 2793 of 2926
# Decoding key: 2794 of 2926
# Decoding key: 2795 of 2926
# Decoding key: 2796 of 2926
# Decoding key: 2797 of 2926
# Decoding key: 2798 of 2926
# Decoding key: 2799 of 2926
# Decoding key: 2800 of 2926
# Decoding key: 2801 of 2926
# Decoding key: 2802 of 2926
# Decoding key: 2803 of 2926
# Decoding key: 2804 of 2926
# Decoding key: 2805 of 2926
# Decoding key: 2806 of 2926
# Decoding key: 2807 of 2926
# Decoding key: 2808 of 2926
# Decoding key: 2809 of 2926
# Decoding key: 2810 of 2926
# Decoding key: 2811 of 2926
# Decoding key: 2812 of 2926
# Decoding key: 2813 of 2926
# Decoding key: 2814 of 2926
# Decoding key: 2815 of 2926
# Decoding key: 2816 of 2926
# Decoding key: 2817 of 2926
# Decoding key: 2818 of 2926
# Decoding key: 2819 of 2926
# Decoding key: 2820 of 2926
# Decoding key: 2821 of 2926
# Decoding key: 2822 of 2926
# Decoding key: 2823 of 2926
# Decoding key: 2824 of 2926
# Decoding key: 2825 of 2926
# Decoding key: 2826 of 2926
# Decoding key: 2827 of 2926
# Decoding key: 2828 of 2926
# Decoding key: 2829 of 2926
# Decoding key: 2830 of 2926
# Decoding key: 2831 of 2926
# Decoding key: 2832 of 2926
# Decoding key: 2833 of 2926
# Decoding key: 2834 of 2926
# Decoding key: 2835 of 2926
# Decoding key: 2836 of 2926
# Decoding key: 2837 of 2926
# Decoding key: 2838 of 2926
# Decoding key: 2839 of 2926
# Decoding key: 2840 of 2926
# Decoding key: 2841 of 2926
# Decoding key: 2842 of 2926
# Decoding key: 2843 of 2926
# Decoding key: 2844 of 2926
# Decoding key: 2845 of 2926
# Decoding key: 2846 of 2926
# Decoding key: 2847 of 2926
# Decoding key: 2848 of 2926
# Decoding key: 2849 of 2926
# Decoding key: 2850 of 2926
# Decoding key: 2851 of 2926
# Decoding key: 2852 of 2926
# Decoding key: 2853 of 2926
# Decoding key: 2854 of 2926
# Decoding key: 2855 of 2926
# Decoding key: 2856 of 2926
# Decoding key: 2857 of 2926
# Decoding key: 2858 of 2926
# Decoding key: 2859 of 2926
# Decoding key: 2860 of 2926
# Decoding key: 2861 of 2926
# Decoding key: 2862 of 2926
# Decoding key: 2863 of 2926
# Decoding key: 2864 of 2926
# Decoding key: 2865 of 2926
# Decoding key: 2866 of 2926
# Decoding key: 2867 of 2926
# Decoding key: 2868 of 2926
# Decoding key: 2869 of 2926
# Decoding key: 2870 of 2926
# Decoding key: 2871 of 2926
# Decoding key: 2872 of 2926
# Decoding key: 2873 of 2926
# Decoding key: 2874 of 2926
# Decoding key: 2875 of 2926
# Decoding key: 2876 of 2926
# Decoding key: 2877 of 2926
# Decoding key: 2878 of 2926
# Decoding key: 2879 of 2926
# Decoding key: 2880 of 2926
# Decoding key: 2881 of 2926
# Decoding key: 2882 of 2926
# Decoding key: 2883 of 2926
# Decoding key: 2884 of 2926
# Decoding key: 2885 of 2926
# Decoding key: 2886 of 2926
# Decoding key: 2887 of 2926
# Decoding key: 2888 of 2926
# Decoding key: 2889 of 2926
# Decoding key: 2890 of 2926
# Decoding key: 2891 of 2926
# Decoding key: 2892 of 2926
# Decoding key: 2893 of 2926
# Decoding key: 2894 of 2926
# Decoding key: 2895 of 2926
# Decoding key: 2896 of 2926
# Decoding key: 2897 of 2926
# Decoding key: 2898 of 2926
# Decoding key: 2899 of 2926
# Decoding key: 2900 of 2926
# Decoding key: 2901 of 2926
# Decoding key: 2902 of 2926
# Decoding key: 2903 of 2926
# Decoding key: 2904 of 2926
# Decoding key: 2905 of 2926
# Decoding key: 2906 of 2926
# Decoding key: 2907 of 2926
# Decoding key: 2908 of 2926
# Decoding key: 2909 of 2926
# Decoding key: 2910 of 2926
# Decoding key: 2911 of 2926
# Decoding key: 2912 of 2926
# Decoding key: 2913 of 2926
# Decoding key: 2914 of 2926
# Decoding key: 2915 of 2926
# Decoding key: 2916 of 2926
# Decoding key: 2917 of 2926
# Decoding key: 2918 of 2926
# Decoding key: 2919 of 2926
# Decoding key: 2920 of 2926
# Decoding key: 2921 of 2926
# Decoding key: 2922 of 2926
# Decoding key: 2923 of 2926
# Decoding key: 2924 of 2926
# Decoding key: 2925 of 2926
# Decoded key (first 3 bytes): SSSSSSSSSSSS
# Done!

# %% [markdown]
# ## Sifting procedure (basis reconciliation)

# %%
def counting(df, block_length):
  raw_keys = pd.DataFrame({'time': [], 'total_pulses': [], 'm_key_mumax': [], 'm_key_mumin': [],
                           'n_key_mumax': [], 'n_key_mumin': [], 'm_check_mumax': [],
                           'm_check_mumin': [], 'n_check_mumax': [], 'n_check_mumin': []})
  i = 0
  jbit = 0
  while i < len(df):
    print('Iteration {} of {}'.format(i, len(df)))
    tot_pulses = 0
    nkmin, nkmax, ncmin, ncmax = 0, 0, 0, 0
    mkmin, mkmax, mcmin, mcmax = 0, 0, 0, 0
    key_time = 0
    while nkmax + ncmax < block_length:
      # Everytime we read a new line a second has passed
      for j in range(jbit, df['total_bits'][i]):
        tot_pulses += 1
        key_time += 1. / df['total_bits'][i] # every bit is read in a fraction of a second since the whole key is read in a second
        if not df['same_basis'][i][j]:
          continue
        if(not df['bob_basis'][i][j]) and df['decoy'][i][j] and df['correctness'][i][j]:
          nkmax += 1 # decoy strong, basis 0 (key), correct
        elif(not df['bob_basis'][i][j]) and (not df['decoy'][i][j]) and (df['correctness'][i][j]):
          nkmin += 1 # decoy weak, basis 0 (key), correct
        elif(df['bob_basis'][i][j]) and df['decoy'][i][j] and (df['correctness'][i][j]):
          ncmax += 1 # decoy strong, basis 1 (check), correct
        elif(df['bob_basis'][i][j]) and (not df['decoy'][i][j]) and (df['correctness'][i][j]):
          ncmin += 1 # decoy weak, basis 1 (check), correct
        elif(not df['bob_basis'][i][j]) and df['decoy'][i][j] and (not df['correctness'][i][j]):
          mkmax += 1 # decoy strong, basis 0 (key), incorrect
        elif(not df['bob_basis'][i][j]) and (not df['decoy'][i][j]) and (not df['correctness'][i][j]):
          mkmin += 1 # decoy weak, basis 0 (key), incorrect
        elif(df['bob_basis'][i][j]) and df['decoy'][i][j] and (not df['correctness'][i][j]):
          mcmax += 1 # decoy strong, basis 1 (check), incorrect
        elif (df['bob_basis'][i][j]) and (not df['decoy'][i][j]) and (not df['correctness'][i][j]):
          mcmin += 1 # decoy weak, basis 1 (check), incorrect
        if nkmax + ncmax >= block_length:
          # If the block is full in the middle of the reading of a key we have to restart from that point
          jbit = j
          break
      if nkmax + ncmax >= block_length:
        break
      i += 1
      jbit = 0
      if i == len(df):
        break
    raw_keys = raw_keys.append({'time': key_time, 'total_pulses': tot_pulses,
                                'm_key_mumax': mkmax, 'm_key_mumin': mkmin,
                                'n_key_mumax': nkmax, 'n_key_mumin': nkmin,
                                'm_check_mumax': mcmax, 'm_check_mumin': mcmin,
                                'n_check_mumax': ncmax, 'n_check_mumin': ncmin}, ignore_index=True)
  return raw_keys

# %%
def basis_reconciliation(block_length, frac_data):
    '''
    Perfoms the basis reconciliation of the protocol, and count the number of errors and
    observations in order to generate a key of length block_length.

    Generates a csv file with the following columns:
    - time: time necessary to reconstruct the key
    - total_pulses: total number of pulses necessary to recontruct the key
    - m_key_mumax: number of errors in the key corresponding to the maximum intensity decoy
    - m_key_mumin: number of errors in the key corresponding to the minimum intensity decoy
    - n_key_mumax: number of observations in the key corresponding to the maximum intensity decoy
    - n_key_mumin: number of observations in the key corresponding to the minimum intensity decoy
    - m_check_mumax: number of errors in the check basis corresponding to the maximum intensity decoy
    - m_check_mumin: number of errors in the check basis corresponding to the minimum intensity decoy
    - n_check_mumax: number of observations in the check basis corresponding to the maximum intensity decoy
    - n_check_mumin: number of observations in the check basis corresponding to the minimum intensity decoy

    Parameters:
      block_length: number of total observations in the key basis
      frac_data: fraction of data to analyze
    '''
    a = pd.read_csv('/content/decoded_keys/decoded_keys_alice.csv')
    b = pd.read_csv('/content/decoded_keys/decoded_keys_bob.csv')
    d = pd.read_csv('/content/decoded_keys/decoded_keys_decoy.csv')
    n_data = int(len(a) * frac_data)
    a = a[:n_data]
    b = b[:n_data]
    d = d[:n_data]
    print('Processing data...')
    a['key'] = a['key'].apply(lambda x: np.array(list(x), dtype=int)) # true if it is the basis X (not key)
    a['basis'] = a['basis'].apply(lambda x: np.array(list(x), dtype=int))
    b['key'] = b['key'].apply(lambda x: np.array(list(x), dtype=int))
    b['basis'] = b['basis'].apply(lambda x: np.array(list(x), dtype=int))
    d = d.drop(columns=['block_size'])
    b = b.drop(columns=['block_size'])
    df = pd.concat([a, b, d], axis=1)
    df.columns = ['alice_state','total_bits', 'alice_key', 'alice_basis',
                  'bob_state', 'bob_key', 'bob_basis', 'decoy_state']
    print('Checking basis and correctness...')
    df['total_bits'] = df.apply(lambda x: len(x['alice_key']), axis=1)
    df['same_basis'] = df.apply(lambda x: x['alice_basis'] == x['bob_basis'], axis=1)
    df['same_bits'] = df.apply(lambda x: x['alice_key'] == x['bob_key'], axis=1)
    df['correctness'] = df.apply(lambda x: x['same_basis'] & x['same_bits'], axis=1)
    # True if the decoy is the strong one
    df['decoy'] = df.apply(lambda x: list(x['decoy_state']) == np.full(len(x['decoy_state']), 'S'), axis=1)
    df['time'] = np.arange(len(df))
    df.to_csv('/content/decoded_keys/basis_reconciliation.csv', index=False)
    # Basis reconciliation:
    # Alice and Bob announce their basis and intensity choices over an authenticated public channel
    # and identify the following sets: X_{k} := {i: a_{i}=b_{i}=X and k_{i}=k} and Z_{k} := {i: a_{i}=b_{i}=Z and k_{i}=k}
    results = counting(df, block_length=block_length)
    # Convert the results into a csv file
    if not os.path.exists('/content/results/'):
      os.mkdir('/content/results/')
    results.to_csv('/content/results/countings_{}_{}.csv'.format(block_length, frac_data), index=False)

# %%
basis_reconciliation(100000, 1)
# Out:
# Processing data...
# Checking basis and correctness...
# Iteration 0 of 2926
# Iteration 9 of 2926
# Iteration 18 of 2926
# Iteration 27 of 2926
# Iteration 37 of 2926
# Iteration 46 of 2926
# Iteration 55 of 2926
# Iteration 65 of 2926
# Iteration 74 of 2926
# Iteration 84 of 2926
# Iteration 93 of 2926
# Iteration 102 of 2926
# Iteration 112 of 2926
# Iteration 121 of 2926
# Iteration 130 of 2926
# Iteration 140 of 2926
# Iteration 149 of 2926
# Iteration 158 of 2926
# Iteration 168 of 2926
# Iteration 177 of 2926
# Iteration 186 of 2926
# Iteration 195 of 2926
# Iteration 205 of 2926
# Iteration 214 of 2926
# Iteration 223 of 2926
# Iteration 233 of 2926
# Iteration 242 of 2926
# Iteration 251 of 2926
# Iteration 261 of 2926
# Iteration 270 of 2926
# Iteration 280 of 2926
# Iteration 289 of 2926
# Iteration 298 of 2926
# Iteration 308 of 2926
# Iteration 317 of 2926
# Iteration 326 of 2926
# Iteration 336 of 2926
# Iteration 345 of 2926
# Iteration 355 of 2926
# Iteration 364 of 2926
# Iteration 373 of 2926
# Iteration 383 of 2926
# Iteration 392 of 2926
# Iteration 401 of 2926
# Iteration 411 of 2926
# Iteration 420 of 2926
# Iteration 429 of 2926
# Iteration 439 of 2926
# Iteration 448 of 2926
# Iteration 457 of 2926
# Iteration 467 of 2926
# Iteration 476 of 2926
# Iteration 485 of 2926
# Iteration 494 of 2926
# Iteration 503 of 2926
# Iteration 513 of 2926
# Iteration 522 of 2926
# Iteration 531 of 2926
# Iteration 541 of 2926
# Iteration 550 of 2926
# Iteration 559 of 2926
# Iteration 569 of 2926
# Iteration 578 of 2926
# Iteration 587 of 2926
# Iteration 597 of 2926
# Iteration 606 of 2926
# Iteration 615 of 2926
# Iteration 624 of 2926
# Iteration 634 of 2926
# Iteration 643 of 2926
# Iteration 652 of 2926
# Iteration 662 of 2926
# Iteration 671 of 2926
# Iteration 680 of 2926
# Iteration 689 of 2926
# Iteration 699 of 2926
# Iteration 708 of 2926
# Iteration 717 of 2926
# Iteration 727 of 2926
# Iteration 736 of 2926
# Iteration 746 of 2926
# Iteration 755 of 2926
# Iteration 764 of 2926
# Iteration 773 of 2926
# Iteration 783 of 2926
# Iteration 792 of 2926
# Iteration 801 of 2926
# Iteration 811 of 2926
# Iteration 820 of 2926
# Iteration 829 of 2926
# Iteration 839 of 2926
# Iteration 848 of 2926
# Iteration 857 of 2926
# Iteration 866 of 2926
# Iteration 876 of 2926
# Iteration 885 of 2926
# Iteration 894 of 2926
# Iteration 904 of 2926
# Iteration 913 of 2926
# Iteration 922 of 2926
# Iteration 931 of 2926
# Iteration 941 of 2926
# Iteration 950 of 2926
# Iteration 959 of 2926
# Iteration 969 of 2926
# Iteration 978 of 2926
# Iteration 987 of 2926
# Iteration 997 of 2926
# Iteration 1006 of 2926
# Iteration 1015 of 2926
# Iteration 1025 of 2926
# Iteration 1034 of 2926
# Iteration 1043 of 2926
# Iteration 1053 of 2926
# Iteration 1062 of 2926
# Iteration 1071 of 2926
# Iteration 1081 of 2926
# Iteration 1090 of 2926
# Iteration 1099 of 2926
# Iteration 1109 of 2926
# Iteration 1118 of 2926
# Iteration 1127 of 2926
# Iteration 1136 of 2926
# Iteration 1146 of 2926
# Iteration 1155 of 2926
# Iteration 1164 of 2926
# Iteration 1174 of 2926
# Iteration 1183 of 2926
# Iteration 1192 of 2926
# Iteration 1202 of 2926
# Iteration 1211 of 2926
# Iteration 1220 of 2926
# Iteration 1230 of 2926
# Iteration 1239 of 2926
# Iteration 1248 of 2926
# Iteration 1257 of 2926
# Iteration 1267 of 2926
# Iteration 1276 of 2926
# Iteration 1285 of 2926
# Iteration 1294 of 2926
# Iteration 1304 of 2926
# Iteration 1313 of 2926
# Iteration 1322 of 2926
# Iteration 1331 of 2926
# Iteration 1341 of 2926
# Iteration 1350 of 2926
# Iteration 1359 of 2926
# Iteration 1369 of 2926
# Iteration 1378 of 2926
# Iteration 1387 of 2926
# Iteration 1397 of 2926
# Iteration 1406 of 2926
# Iteration 1415 of 2926
# Iteration 1425 of 2926
# Iteration 1434 of 2926
# Iteration 1443 of 2926
# Iteration 1453 of 2926
# Iteration 1462 of 2926
# Iteration 1471 of 2926
# Iteration 1481 of 2926
# Iteration 1490 of 2926
# Iteration 1499 of 2926
# Iteration 1508 of 2926
# Iteration 1518 of 2926
# Iteration 1527 of 2926
# Iteration 1537 of 2926
# Iteration 1546 of 2926
# Iteration 1555 of 2926
# Iteration 1565 of 2926
# Iteration 1574 of 2926
# Iteration 1583 of 2926
# Iteration 1592 of 2926
# Iteration 1602 of 2926
# Iteration 1611 of 2926
# Iteration 1620 of 2926
# Iteration 1630 of 2926
# Iteration 1639 of 2926
# Iteration 1648 of 2926
# Iteration 1657 of 2926
# Iteration 1667 of 2926
# Iteration 1676 of 2926
# Iteration 1685 of 2926
# Iteration 1695 of 2926
# Iteration 1704 of 2926
# Iteration 1713 of 2926
# Iteration 1723 of 2926
# Iteration 1732 of 2926
# Iteration 1741 of 2926
# Iteration 1751 of 2926
# Iteration 1760 of 2926
# Iteration 1769 of 2926
# Iteration 1779 of 2926
# Iteration 1788 of 2926
# Iteration 1797 of 2926
# Iteration 1807 of 2926
# Iteration 1816 of 2926
# Iteration 1825 of 2926
# Iteration 1835 of 2926
# Iteration 1844 of 2926
# Iteration 1853 of 2926
# Iteration 1862 of 2926
# Iteration 1872 of 2926
# Iteration 1881 of 2926
# Iteration 1890 of 2926
# Iteration 1900 of 2926
# Iteration 1909 of 2926
# Iteration 1918 of 2926
# Iteration 1928 of 2926
# Iteration 1937 of 2926
# Iteration 1946 of 2926
# Iteration 1956 of 2926
# Iteration 1965 of 2926
# Iteration 1974 of 2926
# Iteration 1984 of 2926
# Iteration 1993 of 2926
# Iteration 2002 of 2926
# Iteration 2012 of 2926
# Iteration 2021 of 2926
# Iteration 2030 of 2926
# Iteration 2039 of 2926
# Iteration 2049 of 2926
# Iteration 2058 of 2926
# Iteration 2067 of 2926
# Iteration 2077 of 2926
# Iteration 2086 of 2926
# Iteration 2095 of 2926
# Iteration 2105 of 2926
# Iteration 2114 of 2926
# Iteration 2124 of 2926
# Iteration 2133 of 2926
# Iteration 2142 of 2926
# Iteration 2152 of 2926
# Iteration 2161 of 2926
# Iteration 2170 of 2926
# Iteration 2180 of 2926
# Iteration 2189 of 2926
# Iteration 2198 of 2926
# Iteration 2208 of 2926
# Iteration 2217 of 2926
# Iteration 2227 of 2926
# Iteration 2236 of 2926
# Iteration 2245 of 2926
# Iteration 2255 of 2926
# Iteration 2264 of 2926
# Iteration 2274 of 2926
# Iteration 2283 of 2926
# Iteration 2292 of 2926
# Iteration 2302 of 2926
# Iteration 2311 of 2926
# Iteration 2320 of 2926
# Iteration 2330 of 2926
# Iteration 2339 of 2926
# Iteration 2348 of 2926
# Iteration 2358 of 2926
# Iteration 2367 of 2926
# Iteration 2376 of 2926
# Iteration 2386 of 2926
# Iteration 2395 of 2926
# Iteration 2404 of 2926
# Iteration 2414 of 2926
# Iteration 2423 of 2926
# Iteration 2432 of 2926
# Iteration 2442 of 2926
# Iteration 2451 of 2926
# Iteration 2460 of 2926
# Iteration 2470 of 2926
# Iteration 2479 of 2926
# Iteration 2488 of 2926
# Iteration 2498 of 2926
# Iteration 2507 of 2926
# Iteration 2517 of 2926
# Iteration 2526 of 2926
# Iteration 2535 of 2926
# Iteration 2545 of 2926
# Iteration 2554 of 2926
# Iteration 2563 of 2926
# Iteration 2573 of 2926
# Iteration 2582 of 2926
# Iteration 2591 of 2926
# Iteration 2601 of 2926
# Iteration 2610 of 2926
# Iteration 2619 of 2926
# Iteration 2629 of 2926
# Iteration 2638 of 2926
# Iteration 2647 of 2926
# Iteration 2657 of 2926
# Iteration 2666 of 2926
# Iteration 2675 of 2926
# Iteration 2685 of 2926
# Iteration 2694 of 2926
# Iteration 2703 of 2926
# Iteration 2712 of 2926
# Iteration 2722 of 2926
# Iteration 2731 of 2926
# Iteration 2741 of 2926
# Iteration 2750 of 2926
# Iteration 2759 of 2926
# Iteration 2769 of 2926
# Iteration 2778 of 2926
# Iteration 2787 of 2926
# Iteration 2797 of 2926
# Iteration 2806 of 2926
# Iteration 2815 of 2926
# Iteration 2824 of 2926
# Iteration 2834 of 2926
# Iteration 2843 of 2926
# Iteration 2852 of 2926
# Iteration 2862 of 2926
# Iteration 2871 of 2926
# Iteration 2880 of 2926
# Iteration 2890 of 2926
# Iteration 2899 of 2926
# Iteration 2908 of 2926
# Iteration 2918 of 2926

# %%
basis_reconciliation(1000000, 1)
# Out:
# Processing data...
# Checking basis and correctness...
# Iteration 0 of 2926
# Iteration 93 of 2926
# Iteration 186 of 2926
# Iteration 280 of 2926
# Iteration 373 of 2926
# Iteration 467 of 2926
# Iteration 559 of 2926
# Iteration 652 of 2926
# Iteration 746 of 2926
# Iteration 839 of 2926
# Iteration 931 of 2926
# Iteration 1025 of 2926
# Iteration 1118 of 2926
# Iteration 1211 of 2926
# Iteration 1304 of 2926
# Iteration 1397 of 2926
# Iteration 1490 of 2926
# Iteration 1583 of 2926
# Iteration 1676 of 2926
# Iteration 1769 of 2926
# Iteration 1862 of 2926
# Iteration 1956 of 2926
# Iteration 2049 of 2926
# Iteration 2142 of 2926
# Iteration 2236 of 2926
# Iteration 2330 of 2926
# Iteration 2423 of 2926
# Iteration 2517 of 2926
# Iteration 2610 of 2926
# Iteration 2703 of 2926
# Iteration 2797 of 2926
# Iteration 2890 of 2926

# %%
basis_reconciliation(10000000, 1)
# Out:
# Processing data...
# Checking basis and correctness...
# Iteration 0 of 2926
# Iteration 931 of 2926
# Iteration 1862 of 2926
# Iteration 2797 of 2926

# %% [markdown]
# ## Security parameters

# %%
class parameters():
  '''
  Parameters:
    alice_key_basis_prob: probability of Alice using the key basis
    alice_check_basis_prob: probability of Alice using the check basis
    bob_key_basis_prob: probability of Bob using the key basis
    bob_check_basis_prob: probability of Bob using the check basis
    decoy_strong_prob: probability of the decoy being the strong one
    decoy_weak_prob: probability of the decoy being the weak one
    decoy_strong_intensity: intensity of the strong decoy
    decoy_weak_intensity: intensity of the weak decoy
    secrecy: secrecy of the protocol
    correctness: correctness of the protocol
    lambda_EC: Alice and Bob perform an error-correction step that reveals at most lambda_{EC} bits of information
  '''
  def __init__(self, alice_key_basis_prob, alice_check_basis_prob,
               bob_key_basis_prob, bob_check_basis_prob,
               decoy_strong_prob, decoy_weak_prob,
               decoy_strong_intensity, decoy_weak_intensity,
               secrecy=1e-9, correctness=1e-15,
               lambda_EC=1.16):
    if alice_check_basis_prob + alice_key_basis_prob != 1:
      raise ValueError('Aice basis probability must sum to 1!')
    if alice_check_basis_prob > 1 or alice_check_basis_prob < 0 or alice_key_basis_prob > 1 or alice_key_basis_prob < 0:
      raise ValueError('Aice basis probability must be between 0 and 1!')
    if bob_check_basis_prob + bob_key_basis_prob != 1:
      raise ValueError('Bob basis probability must sum to 1!')
    if bob_check_basis_prob > 1 or bob_check_basis_prob < 0 or bob_key_basis_prob > 1 or bob_key_basis_prob < 0:
      raise ValueError('Bob basis probability must be between 0 and 1!')
    if decoy_strong_prob + decoy_weak_prob != 1:
      raise ValueError('Decoy probability must sum to 1!')
    if decoy_strong_prob > 1 or decoy_strong_prob < 0 or decoy_weak_prob > 1 or decoy_weak_prob < 0:
      raise ValueError('Decoy probability must be between 0 and 1!')
    if decoy_strong_intensity < decoy_weak_intensity:
      warnings.warn('Decoy strong intensity must be greater than decoy weak intensity!')
      decoy_strong_intensity, decoy_weak_intensity = decoy_weak_intensity, decoy_strong_intensity
    if lambda_EC < 0:
      raise ValueError('lambda_{EC} must be positive, but it is {}'.format(lambda_EC))
    self.a_key_basis_prob = alice_key_basis_prob
    self.a_check_basis_prob = alice_check_basis_prob
    self.b_key_basis_prob = bob_key_basis_prob
    self.b_check_basis_prob = bob_check_basis_prob
    self.d_strong_prob = decoy_strong_prob
    self.d_weak_prob = decoy_weak_prob
    self.d_strong_intensity = decoy_strong_intensity
    self.d_weak_intensity = decoy_weak_intensity
    self.secrecy = secrecy
    self.correctness = correctness
    self.lambda_EC = lambda_EC
    # tau_{n} = sumk p_{k} e^{−k} k^{n}/n! is the total probability to send an n photon state
    self.tau_0 = self.d_weak_prob * np.exp(-self.d_weak_intensity) + self.d_strong_prob * np.exp(-self.d_strong_intensity)
    self.tau_1 = self.d_weak_prob * np.exp(-self.d_weak_intensity) * self.d_weak_intensity + self.d_strong_prob * np.exp(-self.d_strong_intensity) * self.d_strong_intensity
    # Fixed parameters
    self.a = 6
    self.b = 19

# %% [markdown]
# ## Helper functions

# %%
def gamma(a, b, c, d, e_b, e_c, e_d): # not considering error on a
  log = np.log(((c + d) / (c * d * b * (1 - b))) * (21 / a)**2)
  gamma_p = np.sqrt(((c + d) * (1 - b) * b) / (c * d) * log)
  gamma = gamma_p / np.log(2)
  partial_b = ((c + d) * (2 * b - 1) * (log - 1)) / (2 * c * d * np.log(2) * gamma_p)
  partial_c = (b * (b - 1) * (log + 1)) / (2 * c * c * np.log(2) * gamma_p)
  partial_d = (b * (b - 1) * (log + 1)) / (2 * d * d * np.log(2) * gamma_p)
  error = np.sqrt(e_b**2 * partial_b**2 + e_c**2 * partial_c**2 + e_d**2 * partial_d**2)
  return gamma, error

def bin_entropy(x, e_x):
  entropy = -x * np.log2(x) - (1 - x) * np.log2(1 - x)
  error = (np.log(1 - x) - np.log(x)) * e_x / np.log(2)
  return entropy, error

# %% [markdown]
# ## Security bounds

# %%
def security_bounds(block_size, frac_data, time_evolution,
                    alice_key_basis_prob, alice_check_basis_prob,
                    bob_key_basis_prob, bob_check_basis_prob,
                    decoy_strong_prob, decoy_weak_prob,
                    decoy_strong_intensity, decoy_weak_intensity):
    '''
    Computes QBER and SKR with the respective error as proposed in:

    [1] D. Rusca, A. Boaron, F. Grunenfelder, A. Martin, and H. Zbinden.
    Finite-key analysis for the 1-decoy state QKD protocol.
    Applied Physics Letters, 112(17):171104, April 2018.
    DOI: 10.1063/1.5023340.
    URL: https://doi.org/10.1063/1.5023340;

    [2] C. C. W. Lim, M. Curty, N. Walenta, F. Xu, and H. Zbinden.
    Concise security bounds for practical decoy-state quantum key distribution.
    Phys. Rev. A, 89:022307, February 2014.
    DOI: 10.1103/PhysRevA.89.022307.
    URL: https://link.aps.org/doi/10.1103/PhysRevA.89.022307.

    Parameters:
      block_size: block size
      frac_data: fraction of data to read
      alice_key_basis_prob: probability of Alice using the key basis
      alice_check_basis_prob: probability of Alice using the check basis
      bob_key_basis_prob: probability of Bob using the key basis
      bob_check_basis_prob: probability of Bob using the check basis
      decoy_strong_prob: probability of the decoy being the strong one
      decoy_weak_prob: probability of the decoy being the weak one
      decoy_strong_intensity: intensity of the strong decoy
      decoy_weak_intensity: intensity of the weak decoy
    '''

    p = parameters(alice_key_basis_prob, alice_check_basis_prob,
                   bob_key_basis_prob, bob_check_basis_prob,
                   decoy_strong_prob, decoy_weak_prob,
                   decoy_strong_intensity, decoy_weak_intensity,
                   secrecy=1e-9, correctness=1e-15,
                   lambda_EC=1.16)

    if not time_evolution:
        df = pd.read_csv('/content/results/countings_{}_{}.csv'.format(block_size, frac_data))
        df = df.drop(df.index[-1], axis=0)
    else:
        df = pd.read_csv('/content/results/time_evolution_{}_{}.csv'.format(block_size, frac_data))

    # Errors on countings and finite key effect
    for c in df.columns[1:]:
        df[c + '_err'] = np.sqrt(df[c])

    df['n_key_tot'] = df['n_key_mumax'] + df['n_key_mumin']
    df['n_key_tot_err'] = np.sqrt(df['n_key_mumax_err']**2 + df['n_key_mumin_err']**2)

    df['n_check_tot'] = df['n_check_mumax'] + df['n_check_mumin']
    df['n_check_tot_err'] = np.sqrt(df['n_check_mumax_err']**2 + df['n_check_mumin_err']**2)

    df['m_key_tot'] = df['m_key_mumax'] + df['m_key_mumin']
    df['m_key_tot_err'] = np.sqrt(df['m_key_mumax_err']**2 + df['m_key_mumin_err']**2)

    df['m_check_tot'] = df['m_check_mumax'] + df['m_check_mumin']
    df['m_check_tot_err'] = np.sqrt(df['m_check_mumax_err']**2 + df['m_check_mumin_err']**2)

    deltaN_key = np.sqrt(0.5 * df['n_key_tot'] * np.log(19/p.secrecy))
    deltaM_key = np.sqrt(0.5 * df['m_key_tot'] * np.log(19/p.secrecy))
    deltaN_check = np.sqrt(0.5 * df['n_check_tot'] * np.log(19/p.secrecy))
    deltaM_check = np.sqrt(0.5 * df['m_check_tot'] * np.log(19/p.secrecy))

    strong_prefactor = np.exp(p.d_strong_intensity) / p.d_strong_prob
    weak_prefactor = np.exp(p.d_weak_intensity) / p.d_weak_prob

    df['n_key_mumax_plus'] = strong_prefactor * (df['n_key_mumax'] + deltaN_key)
    df['n_key_mumax_min'] = strong_prefactor * (df['n_key_mumax'] - deltaN_key)
    df['n_key_mumax_err_hoeff'] = strong_prefactor * np.sqrt(df['n_key_mumax_err']**2 + (np.log(19./p.secrecy) / (8 * df['n_key_tot'])) * df['n_key_tot_err']**2)

    df['n_key_mumin_plus'] = weak_prefactor * (df['n_key_mumin'] + deltaN_key)
    df['n_key_mumin_min'] = weak_prefactor * (df['n_key_mumin'] - deltaN_key)
    df['n_key_mumin_err_hoeff'] = weak_prefactor * np.sqrt(df['n_key_mumin_err']**2 + (np.log(19./p.secrecy) / (8 * df['n_key_tot'])) * df['n_key_tot_err']**2)

    df['n_check_mumax_plus'] = strong_prefactor * (df['n_check_mumax'] + deltaN_check)
    df['n_check_mumax_min'] = strong_prefactor * (df['n_check_mumax'] - deltaN_check)
    df['n_check_mumax_err_hoeff'] = strong_prefactor * np.sqrt(df['n_check_mumax_err']**2 + (np.log(19./p.secrecy) / (8 * df['n_check_tot'])) * df['n_check_tot_err']**2)

    df['n_check_mumin_plus'] = weak_prefactor * (df['n_check_mumin'] + deltaN_check)
    df['n_check_mumin_min'] = weak_prefactor * (df['n_check_mumin'] - deltaN_check)
    df['n_check_mumin_err_hoeff'] = weak_prefactor * np.sqrt(df['n_check_mumin_err']**2 + (np.log(19./p.secrecy) / (8 * df['n_check_tot'])) * df['n_check_tot_err']**2)

    df['m_key_mumax_plus'] = strong_prefactor * (df['m_key_mumax'] + deltaM_key)
    df['m_key_mumax_min'] = strong_prefactor * (df['m_key_mumax'] - deltaM_key)
    df['m_key_mumax_err_hoeff'] = strong_prefactor * np.sqrt(df['m_key_mumax_err']**2 + (np.log(19./p.secrecy) / (8 * df['m_key_tot'])) * df['m_key_tot_err']**2)

    df['m_key_mumin_plus'] = weak_prefactor * (df['m_key_mumin'] + deltaM_key)
    df['m_key_mumin_min'] = weak_prefactor * (df['m_key_mumin'] - deltaM_key)
    df['m_key_mumin_err_hoeff'] = strong_prefactor * np.sqrt(df['m_key_mumin_err']**2 + (np.log(19./p.secrecy) / (8 * df['m_key_tot'])) * df['m_key_tot_err']**2)

    df['m_check_mumax_plus'] = strong_prefactor * (df['m_check_mumax'] + deltaM_check)
    df['m_check_mumax_min'] = strong_prefactor * (df['m_check_mumax'] - deltaM_check)
    df['m_check_mumax_err_hoeff'] = weak_prefactor * np.sqrt(df['m_check_mumax_err']**2 + (np.log(19./p.secrecy) / (8 * df['m_check_tot'])) * df['m_check_tot_err']**2)

    df['m_check_mumin_plus'] = weak_prefactor * (df['m_check_mumin'] + deltaM_check)
    df['m_check_mumin_min'] = weak_prefactor * (df['m_check_mumin'] - deltaM_check)
    df['m_check_mumin_err_hoeff'] = weak_prefactor * np.sqrt(df['m_check_mumin_err']**2 + (np.log(19./p.secrecy) / (8 * df['m_check_tot'])) * df['m_check_tot_err']**2)

    # QBER
    df['QBER_key'] = df['m_key_tot'] / df['n_key_tot']
    df['QBER_key_err'] = np.sqrt(df['m_key_tot_err']**2 / df['n_key_tot']**2 + df['m_key_tot']**2 * df['n_key_tot_err']**2 / df['n_key_tot']**4)

    df['QBER_check'] = df['m_check_tot'] / df['n_check_tot']
    df['QBER_check_err'] = np.sqrt(df['m_check_tot_err']**2 / df['n_check_tot']**2 + df['m_check_tot']**2 * df['n_check_tot_err']**2 / df['n_check_tot']**4)

    # Lower bound of zero photon detections
    df['s_key_0_low'] = (p.tau_0 / (p.d_strong_intensity - p.d_weak_intensity)) * (p.d_strong_intensity * df['n_key_mumin_min'] - p.d_weak_intensity * df['n_key_mumax_plus'])
    df['s_key_0_low_err'] = (p.tau_0 / (p.d_strong_intensity - p.d_weak_intensity)) * np.sqrt(p.d_strong_intensity**2 * (df['n_key_mumin_err_hoeff']**2 +
                             p.d_weak_intensity**2 * df['n_key_mumax_err_hoeff']**2))

    # Upper bound of zero photon detections
    df['s_key_0_up_strong'] = 2 * (p.tau_0 * df['m_key_mumax_plus'] + np.sqrt(0.5 * df['n_key_tot'] * np.log(19/p.secrecy)))
    df['s_key_0_up_strong_err'] = 2 * np.sqrt((p.tau_0 * df['m_key_mumax_err_hoeff'])**2 + (np.log(19/p.secrecy) / (8 * df['n_key_tot'])) * df['n_key_tot_err']**2)

    # Lower bound of one photon detections key
    df['s_key_1_low'] = (p.tau_1 * p.d_strong_intensity / (p.d_weak_intensity * (p.d_strong_intensity - p.d_weak_intensity))) * (df['n_key_mumin_min']
                        - (p.d_weak_intensity / p.d_strong_intensity)**2 * df['n_key_mumax_plus']
                        - (p.d_strong_intensity**2 - p.d_weak_intensity**2) / (p.d_strong_intensity**2 * p.tau_0) * df['s_key_0_up_strong'])

    df['s_key_1_low_err'] = (p.tau_1 * p.d_strong_intensity / (p.d_weak_intensity * (p.d_strong_intensity - p.d_weak_intensity))) * np.sqrt((df['n_key_mumin_err_hoeff']**2
                            + (p.d_weak_intensity / p.d_strong_intensity)**4 * df['n_key_mumax_err_hoeff']**2
                            + ((p.d_strong_intensity**2 - p.d_weak_intensity**2) / (p.d_strong_intensity**2))**2 * (df['s_key_0_up_strong_err'] / p.tau_0)**2))

    # Lower bound of one photon detections check (needed for phase error)
    df['s_check_0_up_weak'] = 2 * (p.tau_0 * df['m_check_mumin_plus'] + np.sqrt(0.5 * df['n_check_tot'] * np.log(19/p.secrecy)))
    df['s_check_0_up_weak_err'] = 2 * np.sqrt((p.tau_0 * df['m_check_mumax_err_hoeff'])**2 + (np.log(19/p.secrecy) / (8 * df['n_check_tot'])) * df['n_check_tot_err']**2)

    df['s_check_1_low'] = (p.tau_1 * p.d_strong_intensity / (p.d_weak_intensity * (p.d_strong_intensity - p.d_weak_intensity))) * (df['n_check_mumin_min']
                        - (p.d_weak_intensity / p.d_strong_intensity)**2 * df['n_check_mumax_plus']\
                        - (p.d_strong_intensity**2 - p.d_weak_intensity**2) / (p.d_strong_intensity**2) * (df['s_check_0_up_weak'] / p.tau_0))

    df['s_check_1_low_err'] = (p.tau_1 * p.d_strong_intensity / (p.d_weak_intensity * (p.d_strong_intensity - p.d_weak_intensity))) * np.sqrt((df['n_check_mumin_err_hoeff']**2
                            + (p.d_weak_intensity / p.d_strong_intensity)**4 * df['n_check_mumax_err_hoeff']**2
                            + ((p.d_strong_intensity**2 - p.d_weak_intensity**2) / (p.d_strong_intensity**2 * p.tau_0))**2 * df['s_check_0_up_weak_err']**2))

    df['v_check_1_up'] = (p.tau_1 / (p.d_strong_intensity - p.d_weak_intensity)) * (df['m_check_mumax_plus'] - df['m_check_mumin_min'])
    df['v_check_1_up_err'] = (p.tau_1 / (p.d_strong_intensity - p.d_weak_intensity)) * np.sqrt(df['m_check_mumax_err_hoeff']**2 + df['m_check_mumin_err_hoeff']**2)

    err_temp = np.sqrt((df['v_check_1_up_err'] / df['s_check_1_low'])**2 + (df['v_check_1_up'] * df['s_check_1_low_err'] / df['s_check_1_low']**2)**2)
    df['gamma'], df['gamma_err'] = gamma(p.secrecy, df['v_check_1_up'] / df['s_check_1_low'], df['s_key_1_low'],
                                         df['s_check_1_low'], err_temp, df['s_key_1_low_err'], df['s_check_1_low_err'])
    # Phase error
    df['phi_up'] = df['v_check_1_up'] / df['s_check_1_low'] + df['gamma']
    df['phi_up_err'] = np.sqrt(err_temp**2 + df['gamma_err']**2)

    df[df < 0] = 0 # set to zero non physical values

    entropy, error = bin_entropy(df['phi_up'], df['phi_up_err'])
    p.lambda_EC, _ = bin_entropy(np.mean(df['QBER_key']), 0)
    p.lambda_EC = p.lambda_EC * 1.16
    df['secret_key_length'] = df['s_key_0_low'] + df['s_key_1_low']*(1 - entropy) - p.lambda_EC - 6 * np.log2(19/p.secrecy) - np.log2(2/p.correctness)
    df['secret_key_length_err'] = np.sqrt(df['s_key_0_low_err']**2 + (df['s_key_1_low_err']*(1 - entropy))**2 + (df['s_key_1_low_err'] * error)**2)

    repetition_rate = 1
    df['SKR'] = df['secret_key_length'] * repetition_rate / df['total_pulses']
    df['SKR_err'] = np.sqrt((df['secret_key_length_err'] * repetition_rate / df['total_pulses'])**2 +
                            (df['secret_key_length'] * repetition_rate * df['total_pulses_err'] / df['total_pulses']**2)**2)

    if not time_evolution:
        df.to_csv('/content/results/{}_{}_results.csv'.format(block_size, frac_data), index=False)
    else:
        df.to_csv('/content/results/time_evolution_{}_{}_results.csv'.format(block_size, frac_data), index=False)

# %%
security_bounds(100000, 1, None, 0.90, 0.10, 0.50, 0.50, 0.70, 0.30, 0.6, 0.1818)
security_bounds(1000000, 1, None, 0.90, 0.10, 0.50, 0.50, 0.70, 0.30, 0.6, 0.1818)
security_bounds(10000000, 1, None, 0.90, 0.10, 0.50, 0.50, 0.70, 0.30, 0.6, 0.1818)

# %% [markdown]
# ## Time evolution

# %%
def time_evolution(results_path, filename):
    '''
    From previous computations, computes the SKR and all the bounds by
    considering each time all data from the beginning to a certain time.
    This allows to show the dependence of a certain parameter on the time.
    '''
    df = pd.read_csv(filename)
    results = pd.DataFrame({'time': [], 'total_pulses': [], 'm_key_mumax': [], 'm_key_mumin': [],
                            'n_key_mumax': [], 'n_key_mumin': [], 'm_check_mumax': [],
                            'm_check_mumin': [], 'n_check_mumax': [], 'n_check_mumin': []})

    for i in range(len(df)):
      a = df[:i+1]
      a = a.sum()
      results = results.append({'time': a['time'], 'total_pulses': a['total_pulses'],
                                'm_key_mumax': a['m_key_mumax'], 'm_key_mumin': a['m_key_mumin'],
                                'n_key_mumax': a['n_key_mumax'], 'n_key_mumin': a['n_key_mumin'],
                                'm_check_mumax': a['m_check_mumax'], 'm_check_mumin': a['m_check_mumin'],
                                'n_check_mumax': a['n_check_mumax'], 'n_check_mumin': a['n_check_mumin']}, ignore_index=True)

    results.to_csv(results_path, index=False)

# %%
time_evolution('/content/results/time_evolution_100000_1.csv', '/content/results/100000_1_results.csv')
time_evolution('/content/results/time_evolution_1000000_1.csv', '/content/results/1000000_1_results.csv')
time_evolution('/content/results/time_evolution_10000000_1.csv', '/content/results/10000000_1_results.csv')

# %% [markdown]
# ## Download the results

# %%
# Specify the folder path and zip filename
folder_path = "/content/decoded_keys"
zip_filename = "decoded_keys_results.zip"
# Zip all files inside the folder
# !zip -r {zip_filename} {folder_path}/*
# Download the zip file
gc_files.download(zip_filename)
# Out:
#   adding: content/decoded_keys/basis_reconciliation.csv (deflated 78%)
#   adding: content/decoded_keys/decoded_keys_alice.csv (deflated 83%)
#   adding: content/decoded_keys/decoded_keys_bob.csv (deflated 77%)
#   adding: content/decoded_keys/decoded_keys_decoy.csv (deflated 90%)

# %%
# Specify the folder path and zip filename
folder_path = "/content/results"
zip_filename = "security_analysis_results.zip"
# Zip all files inside the folder
# !zip -r {zip_filename} {folder_path}/*
# Download the zip file
gc_files.download(zip_filename)
# Out:
#   adding: content/results/10000000_1_results.csv (deflated 53%)
#   adding: content/results/1000000_1_results.csv (deflated 50%)
#   adding: content/results/100000_1_results.csv (deflated 55%)
#   adding: content/results/countings_10000000_1.csv (deflated 49%)
#   adding: content/results/countings_1000000_1.csv (deflated 60%)
#   adding: content/results/countings_100000_1.csv (deflated 67%)
#   adding: content/results/time_evolution_10000000_1.csv (deflated 47%)
#   adding: content/results/time_evolution_1000000_1.csv (deflated 53%)
#   adding: content/results/time_evolution_100000_1.csv (deflated 56%)
